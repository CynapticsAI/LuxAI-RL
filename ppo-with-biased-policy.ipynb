# %% [markdown]
# # Lux AI Deep Reinforcement Learning Environment Example
# See https://github.com/glmcdona/LuxPythonEnvGym for environment project and updates.
#
# This is a python replica of the Lux game engine to speed up training. It reformats the agent problem into making a action decision per-unit for the team.

# %%
# !pip install git+https://github.com/glmcdona/LuxPythonEnvGym.git
# !pip install kaggle-environments -U
# Out:
# Collecting git+https://github.com/glmcdona/LuxPythonEnvGym.git
#   Cloning https://github.com/glmcdona/LuxPythonEnvGym.git to /tmp/pip-req-build-g0fsug7x
#   Running command git clone -q https://github.com/glmcdona/LuxPythonEnvGym.git /tmp/pip-req-build-g0fsug7x
# Requirement already satisfied: pytest in /opt/conda/lib/python3.7/site-packages (from luxai2021==0.1.0) (6.2.4)
# Collecting stable_baselines3==1.2.1a2
#   Downloading stable_baselines3-1.2.1a2-py3-none-any.whl (173 kB)
#      |████████████████████████████████| 173 kB 11.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from luxai2021==0.1.0) (1.19.5)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.7/site-packages (from luxai2021==0.1.0) (2.4.1)
# Collecting gym==0.19.0
#   Downloading gym-0.19.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 59.7 MB/s eta 0:00:01
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from gym==0.19.0->luxai2021==0.1.0) (1.6.0)
# Collecting torch>=1.8.1
#   Downloading torch-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (887.5 MB)
#      |████████████████████████████████| 887.5 MB 5.7 kB/s  eta 0:00:01     |████████████████████████████▋   | 795.0 MB 43.6 MB/s eta 0:00:03
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from stable_baselines3==1.2.1a2->luxai2021==0.1.0) (1.2.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from stable_baselines3==1.2.1a2->luxai2021==0.1.0) (3.4.2)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      |████████████████████████████████| 317.1 MB 21 kB/s s eta 0:00:01
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      |████████████████████████████████| 849 kB 53.6 MB/s eta 0:00:01
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 58.3 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.7/site-packages (from torch>=1.8.1->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (3.7.4.3)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      |████████████████████████████████| 557.1 MB 7.2 kB/s  eta 0:00:01     |██████▋                         | 115.7 MB 49.6 MB/s eta 0:00:09     |██████████████████▌             | 321.9 MB 73.6 MB/s eta 0:00:04
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.1->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (49.6.0.post20210108)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.1->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (0.36.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (8.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (1.3.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (2021.1)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (1.10.0)
# Requirement already satisfied: toml in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (0.10.2)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (0.13.1)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (21.2.0)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (1.1.1)
# Requirement already satisfied: importlib-metadata>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (3.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (20.9)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->luxai2021==0.1.0) (3.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (1.30.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (0.4.4)
# Requirement already satisfied: grpcio>=1.24.3 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (1.32.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (1.8.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (0.12.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (2.25.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (2.0.1)
# Requirement already satisfied: protobuf>=3.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (3.17.3)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard->luxai2021==0.1.0) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard->luxai2021==0.1.0) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard->luxai2021==0.1.0) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->luxai2021==0.1.0) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard->luxai2021==0.1.0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->luxai2021==0.1.0) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->luxai2021==0.1.0) (1.26.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->luxai2021==0.1.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->luxai2021==0.1.0) (4.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->luxai2021==0.1.0) (3.1.1)
# Building wheels for collected packages: luxai2021, gym
#   Building wheel for luxai2021 (setup.py) ... done
#   Created wheel for luxai2021: filename=luxai2021-0.1.0-py3-none-any.whl size=46730 sha256=0bbcc9608f3be7ef36456181f47562343227d9d62b23ec2bf0f1495f001ca364
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cqvd74vw/wheels/b2/22/ee/884dd4091817cdc45e2980f439823344fb99cad2a54fa05e65
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.19.0-py3-none-any.whl size=1663118 sha256=6bc991e0456cf038671f79360339168d7b7edd640fed4c4429c7883bbf4c180e
#   Stored in directory: /root/.cache/pip/wheels/ef/9d/70/8bea53f7edec2fdb4f98d9d64ac9f11aea95dfcb98099d7712
# Successfully built luxai2021 gym
# Installing collected packages: nvidia-cublas-cu11, nvidia-cudnn-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, torch, gym, stable-baselines3, luxai2021
#   Attempting uninstall: torch
#     Found existing installation: torch 1.7.0
#     Uninstalling torch-1.7.0:
#       Successfully uninstalled torch-1.7.0
#   Attempting uninstall: gym
#     Found existing installation: gym 0.18.3
#     Uninstalling gym-0.18.3:
#       Successfully uninstalled gym-0.18.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kornia 0.5.5 requires numpy<=1.19, but you have numpy 1.19.5 which is incompatible.
# fastai 2.2.7 requires torch<1.8,>=1.7.0, but you have torch 1.13.1 which is incompatible.
# allennlp 2.5.0 requires torch<1.9.0,>=1.6.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed gym-0.19.0 luxai2021-0.1.0 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 stable-baselines3-1.2.1a2 torch-1.13.1
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Requirement already satisfied: kaggle-environments in /opt/conda/lib/python3.7/site-packages (1.7.11)
# Collecting kaggle-environments
#   Downloading kaggle_environments-1.14.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 8.3 MB/s eta 0:00:01
# Collecting stable-baselines3==1.7.0
#   Downloading stable_baselines3-1.7.0-py3-none-any.whl (171 kB)
#      |████████████████████████████████| 171 kB 43.1 MB/s eta 0:00:01
# Collecting PettingZoo==1.12.0
#   Downloading PettingZoo-1.12.0.tar.gz (756 kB)
#      |████████████████████████████████| 756 kB 58.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.19.5 in /opt/conda/lib/python3.7/site-packages (from kaggle-environments) (1.19.5)
# Collecting gym==0.21.0
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      |████████████████████████████████| 1.5 MB 53.1 MB/s eta 0:00:01
# Collecting pickle5==0.0.12
#   Downloading pickle5-0.0.12-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (256 kB)
#      |████████████████████████████████| 256 kB 47.0 MB/s eta 0:00:01
# Requirement already satisfied: Flask>=1.1.2 in /opt/conda/lib/python3.7/site-packages (from kaggle-environments) (2.0.1)
# Requirement already satisfied: requests>=2.25.1 in /opt/conda/lib/python3.7/site-packages (from kaggle-environments) (2.25.1)
# Requirement already satisfied: jsonschema>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from kaggle-environments) (3.2.0)
# Collecting vec-noise>=1.1.4
#   Downloading vec_noise-1.1.4.zip (134 kB)
#      |████████████████████████████████| 134 kB 55.8 MB/s eta 0:00:01
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from gym==0.21.0->kaggle-environments) (1.6.0)
# Collecting importlib_metadata>=4.8.1
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from stable-baselines3==1.7.0->kaggle-environments) (3.4.2)
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: torch>=1.11 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3==1.7.0->kaggle-environments) (1.13.1)
# Collecting typing-extensions<5,>=4.0
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from stable-baselines3==1.7.0->kaggle-environments) (1.2.4)
# Requirement already satisfied: Jinja2>=3.0 in /opt/conda/lib/python3.7/site-packages (from Flask>=1.1.2->kaggle-environments) (3.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in /opt/conda/lib/python3.7/site-packages (from Flask>=1.1.2->kaggle-environments) (2.0.1)
# Requirement already satisfied: click>=7.1.2 in /opt/conda/lib/python3.7/site-packages (from Flask>=1.1.2->kaggle-environments) (7.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/conda/lib/python3.7/site-packages (from Flask>=1.1.2->kaggle-environments) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib_metadata>=4.8.1->gym==0.21.0->kaggle-environments) (3.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.7/site-packages (from Jinja2>=3.0->Flask>=1.1.2->kaggle-environments) (2.0.1)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (0.17.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (49.6.0.post20210108)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.25.1->kaggle-environments) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.25.1->kaggle-environments) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=2.25.1->kaggle-environments) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.25.1->kaggle-environments) (2021.5.30)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3==1.7.0->kaggle-environments) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3==1.7.0->kaggle-environments) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3==1.7.0->kaggle-environments) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3==1.7.0->kaggle-environments) (11.7.99)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11->stable-baselines3==1.7.0->kaggle-environments) (0.36.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3==1.7.0->kaggle-environments) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3==1.7.0->kaggle-environments) (8.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3==1.7.0->kaggle-environments) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3==1.7.0->kaggle-environments) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3==1.7.0->kaggle-environments) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->stable-baselines3==1.7.0->kaggle-environments) (2021.1)
# Building wheels for collected packages: gym, PettingZoo, vec-noise
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616826 sha256=37ab10f416f6cc28d9f814fc998eedae3aefde50ee1deb35df6036c9cea8f20b
#   Stored in directory: /root/.cache/pip/wheels/76/ee/9c/36bfe3e079df99acf5ae57f4e3464ff2771b34447d6d2f2148
#   Building wheel for PettingZoo (setup.py) ... done
#   Created wheel for PettingZoo: filename=PettingZoo-1.12.0-py3-none-any.whl size=873565 sha256=c984bb406c0125f1b610972d73040f89304424f83e247eb15880a61fec4193b3
#   Stored in directory: /root/.cache/pip/wheels/50/1d/da/6a09fdb8c06333aa981d1239e40cc8aa5cbac80b30498b1e85
#   Building wheel for vec-noise (setup.py) ... done
#   Created wheel for vec-noise: filename=vec_noise-1.1.4-cp37-cp37m-linux_x86_64.whl size=86381 sha256=fad0ca9de5f318d89bd18d0dacd9ae54a624d0283a581ec0e7f1f5f28222e930
#   Stored in directory: /root/.cache/pip/wheels/fc/0c/19/5932b4834cf3204ed2ae845e788f07c79b3279c302d55d6fa8
# Successfully built gym PettingZoo vec-noise
# Installing collected packages: typing-extensions, importlib-metadata, gym, vec-noise, stable-baselines3, pickle5, PettingZoo, kaggle-environments
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.4.0
#     Uninstalling importlib-metadata-3.4.0:
#       Successfully uninstalled importlib-metadata-3.4.0
#   Attempting uninstall: gym
#     Found existing installation: gym 0.19.0
#     Uninstalling gym-0.19.0:
#       Successfully uninstalled gym-0.19.0
#   Attempting uninstall: stable-baselines3
#     Found existing installation: stable-baselines3 1.2.1a2
#     Uninstalling stable-baselines3-1.2.1a2:
#       Successfully uninstalled stable-baselines3-1.2.1a2
#   Attempting uninstall: kaggle-environments
#     Found existing installation: kaggle-environments 1.7.11
#     Uninstalling kaggle-environments-1.7.11:
#       Successfully uninstalled kaggle-environments-1.7.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.4.1 requires typing-extensions~=3.7.4, but you have typing-extensions 4.7.1 which is incompatible.
# luxai2021 0.1.0 requires gym==0.19.0, but you have gym 0.21.0 which is incompatible.
# luxai2021 0.1.0 requires stable-baselines3==1.2.1a2, but you have stable-baselines3 1.7.0 which is incompatible.
# kornia 0.5.5 requires numpy<=1.19, but you have numpy 1.19.5 which is incompatible.
# fastai 2.2.7 requires torch<1.8,>=1.7.0, but you have torch 1.13.1 which is incompatible.
# arviz 0.11.2 requires typing-extensions<4,>=3.7.4.3, but you have typing-extensions 4.7.1 which is incompatible.
# allennlp 2.5.0 requires torch<1.9.0,>=1.6.0, but you have torch 1.13.1 which is incompatible.
# aiobotocore 1.3.1 requires botocore<1.20.50,>=1.20.49, but you have botocore 1.20.105 which is incompatible.
# Successfully installed PettingZoo-1.12.0 gym-0.21.0 importlib-metadata-4.13.0 kaggle-environments-1.14.0 pickle5-0.0.12 stable-baselines3-1.7.0 typing-extensions-4.7.1 vec-noise-1.1.4
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %% [markdown]
# ## Use GPU if available
# Note: GPU provides very little speedup. I recommend using a CPU-only notebook usually.

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
print(device)

# %% [markdown]
# # Define the RL agent logic
# Edit this agent logic to implement your own observations, action space, and reward shaping.

# %%
# %%writefile agent_policy.py
from luxai2021.game.match_controller import ActionSequence
import sys
import time
from functools import partial  # pip install functools

import numpy as np
from gym import spaces
import copy
import random

from luxai2021.env.agent import Agent
from luxai2021.game.actions import *
from luxai2021.game.game_constants import GAME_CONSTANTS
from luxai2021.game.position import Position


# https://codereview.stackexchange.com/questions/28207/finding-the-closest-point-to-a-list-of-points
def closest_node(node, nodes):
    dist_2 = np.sum((nodes - node) ** 2, axis=1)
    return np.argmin(dist_2)
def furthest_node(node, nodes):
    dist_2 = np.sum((nodes - node) ** 2, axis=1)
    return np.argmax(dist_2)

def smart_transfer_to_nearby(game, team, unit_id, unit, target_type_restriction=None, **kwarg):
    """
    Smart-transfers from the specified unit to a nearby neighbor. Prioritizes any
    nearby carts first, then any worker. Transfers the resource type which the unit
    has most of. Picks which cart/worker based on choosing a target that is most-full
    but able to take the most amount of resources.

    Args:
        team ([type]): [description]
        unit_id ([type]): [description]

    Returns:
        Action: Returns a TransferAction object, even if the request is an invalid
                transfer. Use TransferAction.is_valid() to check validity.
    """

    # Calculate how much resources could at-most be transferred
    resource_type = None
    resource_amount = 0
    target_unit = None

    if unit != None:
        for type, amount in unit.cargo.items():
            if amount > resource_amount:
                resource_type = type
                resource_amount = amount

        # Find the best nearby unit to transfer to
        unit_cell = game.map.get_cell_by_pos(unit.pos)
        adjacent_cells = game.map.get_adjacent_cells(unit_cell)

        
        for c in adjacent_cells:
            for id, u in c.units.items():
                # Apply the unit type target restriction
                if target_type_restriction == None or u.type == target_type_restriction:
                    if u.team == team:
                        # This unit belongs to our team, set it as the winning transfer target
                        # if it's the best match.
                        if target_unit is None:
                            target_unit = u
                        else:
                            # Compare this unit to the existing target
                            if target_unit.type == u.type:
                                # Transfer to the target with the least capacity, but can accept
                                # all of our resources
                                if( u.get_cargo_space_left() >= resource_amount and 
                                    target_unit.get_cargo_space_left() >= resource_amount ):
                                    # Both units can accept all our resources. Prioritize one that is most-full.
                                    if u.get_cargo_space_left() < target_unit.get_cargo_space_left():
                                        # This new target it better, it has less space left and can take all our
                                        # resources
                                        target_unit = u
                                    
                                elif( target_unit.get_cargo_space_left() >= resource_amount ):
                                    # Don't change targets. Current one is best since it can take all
                                    # the resources, but new target can't.
                                    pass
                                    
                                elif( u.get_cargo_space_left() > target_unit.get_cargo_space_left() ):
                                    # Change targets, because neither target can accept all our resources and 
                                    # this target can take more resources.
                                    target_unit = u
                            elif u.type == Constants.UNIT_TYPES.CART:
                                # Transfer to this cart instead of the current worker target
                                target_unit = u
    
    # Build the transfer action request
    target_unit_id = None
    if target_unit is not None:
        target_unit_id = target_unit.id

        # Update the transfer amount based on the room of the target
        if target_unit.get_cargo_space_left() < resource_amount:
            resource_amount = target_unit.get_cargo_space_left()
    
    return TransferAction(team, unit_id, target_unit_id, resource_type, resource_amount)

########################################################################################################################
# This is the Agent that you need to design for the competition
########################################################################################################################
class AgentPolicy(Agent):
    def __init__(self, mode="train", model=None) -> None:
        """
        Arguments:
            mode: "train" or "inference", which controls if this agent is for training or not.
            model: The pretrained model, or if None it will operate in training mode.
        """
        super().__init__()
        self.model = model
        self.mode = mode
        
        self.stats = None
        self.stats_last_game = None

        # Define action and observation space
        # They must be gym.spaces objects
        # Example when using discrete actions:
        self.actionSpaceMapUnits = [
            partial(MoveAction, direction=Constants.DIRECTIONS.CENTER),  # This is the do-nothing action
            partial(MoveAction, direction=Constants.DIRECTIONS.NORTH),
            partial(MoveAction, direction=Constants.DIRECTIONS.WEST),
            partial(MoveAction, direction=Constants.DIRECTIONS.SOUTH),
            partial(MoveAction, direction=Constants.DIRECTIONS.EAST),
            smart_transfer_to_nearby, # Transfer to nearby
            SpawnCityAction,
            #PillageAction,
        ]
        self.actionSpaceMapCities = [
            SpawnWorkerAction,
            SpawnCartAction,
            ResearchAction,
        ]

        self.action_space = spaces.Discrete(max(len(self.actionSpaceMapUnits), len(self.actionSpaceMapCities)))
        

        # Observation space: (Basic minimum for a miner agent)
        # Object:
        #   1x is worker
        #   1x is cart
        #   1x is citytile
        #
        #   5x direction_nearest_wood
        #   1x distance_nearest_wood
        #   1x amount
        #
        #   5x direction_nearest_coal
        #   1x distance_nearest_coal
        #   1x amount
        #
        #   5x direction_nearest_uranium
        #   1x distance_nearest_uranium
        #   1x amount
        #
        #   5x direction_nearest_city
        #   1x distance_nearest_city
        #   1x amount of fuel
        #
        #   28x (the same as above, but direction, distance, and amount to the furthest of each)
        #
        #   5x direction_nearest_worker
        #   1x distance_nearest_worker
        #   1x amount of cargo
        # Unit:
        #   1x cargo size
        # State:
        #   1x is night
        #   1x percent of game done
        #   2x citytile counts [cur player, opponent]
        #   2x worker counts [cur player, opponent]
        #   2x cart counts [cur player, opponent]
        #   1x research points [cur player]
        #   1x researched coal [cur player]
        #   1x researched uranium [cur player]
        self.observation_shape = (3 + 7 * 5 * 2 + 1 + 1 + 1 + 2 + 2 + 2 + 3,)
        self.observation_space = spaces.Box(low=0, high=1, shape=
        self.observation_shape, dtype=np.float16)

        self.object_nodes = {}

    def get_agent_type(self):
        """
        Returns the type of agent. Use AGENT for inference, and LEARNING for training a model.
        """
        if self.mode == "train":
            return Constants.AGENT_TYPE.LEARNING
        else:
            return Constants.AGENT_TYPE.AGENT

    def get_observation(self, game, unit, city_tile, team, is_new_turn):
        """
        Implements getting a observation from the current game for this unit or city
        """
        observation_index = 0
        if is_new_turn:
            # It's a new turn this event. This flag is set True for only the first observation from each turn.
            # Update any per-turn fixed observation space that doesn't change per unit/city controlled.

            # Build a list of object nodes by type for quick distance-searches
            self.object_nodes = {}

            # Add resources
            for cell in game.map.resources:
                if cell.resource.type not in self.object_nodes:
                    self.object_nodes[cell.resource.type] = np.array([[cell.pos.x, cell.pos.y]])
                else:
                    self.object_nodes[cell.resource.type] = np.concatenate(
                        (
                            self.object_nodes[cell.resource.type],
                            [[cell.pos.x, cell.pos.y]]
                        ),
                        axis=0
                    )

            # Add your own and opponent units
            for t in [team, (team + 1) % 2]:
                for u in game.state["teamStates"][team]["units"].values():
                    key = str(u.type)
                    if t != team:
                        key = str(u.type) + "_opponent"

                    if key not in self.object_nodes:
                        self.object_nodes[key] = np.array([[u.pos.x, u.pos.y]])
                    else:
                        self.object_nodes[key] = np.concatenate(
                            (
                                self.object_nodes[key],
                                [[u.pos.x, u.pos.y]]
                            )
                            , axis=0
                        )

            # Add your own and opponent cities
            for city in game.cities.values():
                for cells in city.city_cells:
                    key = "city"
                    if city.team != team:
                        key = "city_opponent"

                    if key not in self.object_nodes:
                        self.object_nodes[key] = np.array([[cells.pos.x, cells.pos.y]])
                    else:
                        self.object_nodes[key] = np.concatenate(
                            (
                                self.object_nodes[key],
                                [[cells.pos.x, cells.pos.y]]
                            )
                            , axis=0
                        )

        # Observation space: (Basic minimum for a miner agent)
        # Object:
        #   1x is worker
        #   1x is cart
        #   1x is citytile
        #   5x direction_nearest_wood
        #   1x distance_nearest_wood
        #   1x amount
        #
        #   5x direction_nearest_coal
        #   1x distance_nearest_coal
        #   1x amount
        #
        #   5x direction_nearest_uranium
        #   1x distance_nearest_uranium
        #   1x amount
        #
        #   5x direction_nearest_city
        #   1x distance_nearest_city
        #   1x amount of fuel
        #
        #   5x direction_nearest_worker
        #   1x distance_nearest_worker
        #   1x amount of cargo
        #
        #   28x (the same as above, but direction, distance, and amount to the furthest of each)
        #
        # Unit:
        #   1x cargo size
        # State:
        #   1x is night
        #   1x percent of game done
        #   2x citytile counts [cur player, opponent]
        #   2x worker counts [cur player, opponent]
        #   2x cart counts [cur player, opponent]
        #   1x research points [cur player]
        #   1x researched coal [cur player]
        #   1x researched uranium [cur player]
        obs = np.zeros(self.observation_shape)
        
        # Update the type of this object
        #   1x is worker
        #   1x is cart
        #   1x is citytile
        observation_index = 0
        if unit is not None:
            if unit.type == Constants.UNIT_TYPES.WORKER:
                obs[observation_index] = 1.0 # Worker
            else:
                obs[observation_index+1] = 1.0 # Cart
        if city_tile is not None:
            obs[observation_index+2] = 1.0 # CityTile
        observation_index += 3
        
        pos = None
        if unit is not None:
            pos = unit.pos
        else:
            pos = city_tile.pos

        if pos is None:
            observation_index += 7 * 5 * 2
        else:
            # Encode the direction to the nearest objects
            #   5x direction_nearest
            #   1x distance
            for distance_function in [closest_node, furthest_node]:
                for key in [
                    Constants.RESOURCE_TYPES.WOOD,
                    Constants.RESOURCE_TYPES.COAL,
                    Constants.RESOURCE_TYPES.URANIUM,
                    "city",
                    str(Constants.UNIT_TYPES.WORKER)]:
                    # Process the direction to and distance to this object type

                    # Encode the direction to the nearest object (excluding itself)
                    #   5x direction
                    #   1x distance
                    if key in self.object_nodes:
                        if (
                                (key == "city" and city_tile is not None) or
                                (unit is not None and str(unit.type) == key and len(game.map.get_cell_by_pos(unit.pos).units) <= 1 )
                        ):
                            # Filter out the current unit from the closest-search
                            closest_index = closest_node((pos.x, pos.y), self.object_nodes[key])
                            filtered_nodes = np.delete(self.object_nodes[key], closest_index, axis=0)
                        else:
                            filtered_nodes = self.object_nodes[key]

                        if len(filtered_nodes) == 0:
                            # No other object of this type
                            obs[observation_index + 5] = 1.0
                        else:
                            # There is another object of this type
                            closest_index = distance_function((pos.x, pos.y), filtered_nodes)

                            if closest_index is not None and closest_index >= 0:
                                closest = filtered_nodes[closest_index]
                                closest_position = Position(closest[0], closest[1])
                                direction = pos.direction_to(closest_position)
                                mapping = {
                                    Constants.DIRECTIONS.CENTER: 0,
                                    Constants.DIRECTIONS.NORTH: 1,
                                    Constants.DIRECTIONS.WEST: 2,
                                    Constants.DIRECTIONS.SOUTH: 3,
                                    Constants.DIRECTIONS.EAST: 4,
                                }
                                obs[observation_index + mapping[direction]] = 1.0  # One-hot encoding direction

                                # 0 to 1 distance
                                distance = pos.distance_to(closest_position)
                                obs[observation_index + 5] = min(distance / 20.0, 1.0)

                                # 0 to 1 value (amount of resource, cargo for unit, or fuel for city)
                                if key == "city":
                                    # City fuel as % of upkeep for 200 turns
                                    c = game.cities[game.map.get_cell_by_pos(closest_position).city_tile.city_id]
                                    obs[observation_index + 6] = min(
                                        c.fuel / (c.get_light_upkeep() * 200.0),
                                        1.0
                                    )
                                elif key in [Constants.RESOURCE_TYPES.WOOD, Constants.RESOURCE_TYPES.COAL,
                                             Constants.RESOURCE_TYPES.URANIUM]:
                                    # Resource amount
                                    obs[observation_index + 6] = min(
                                        game.map.get_cell_by_pos(closest_position).resource.amount / 500,
                                        1.0
                                    )
                                else:
                                    # Unit cargo
                                    obs[observation_index + 6] = min(
                                        next(iter(game.map.get_cell_by_pos(
                                            closest_position).units.values())).get_cargo_space_left() / 100,
                                        1.0
                                    )

                    observation_index += 7

        if unit is not None:
            # Encode the cargo space
            #   1x cargo size
            obs[observation_index] = unit.get_cargo_space_left() / GAME_CONSTANTS["PARAMETERS"]["RESOURCE_CAPACITY"][
                "WORKER"]
            observation_index += 1
        else:
            observation_index += 1

        # Game state observations

        #   1x is night
        obs[observation_index] = game.is_night()
        observation_index += 1

        #   1x percent of game done
        obs[observation_index] = game.state["turn"] / GAME_CONSTANTS["PARAMETERS"]["MAX_DAYS"]
        observation_index += 1

        #   2x citytile counts [cur player, opponent]
        #   2x worker counts [cur player, opponent]
        #   2x cart counts [cur player, opponent]
        max_count = 30
        for key in ["city", str(Constants.UNIT_TYPES.WORKER), str(Constants.UNIT_TYPES.CART)]:
            if key in self.object_nodes:
                obs[observation_index] = len(self.object_nodes[key]) / max_count
            if (key + "_opponent") in self.object_nodes:
                obs[observation_index + 1] = len(self.object_nodes[(key + "_opponent")]) / max_count
            observation_index += 2

        #   1x research points [cur player]
        #   1x researched coal [cur player]
        #   1x researched uranium [cur player]
        obs[observation_index] = game.state["teamStates"][team]["researchPoints"] / 200.0
        obs[observation_index+1] = float(game.state["teamStates"][team]["researched"]["coal"])
        obs[observation_index+2] = float(game.state["teamStates"][team]["researched"]["uranium"])

        return obs

    def action_code_to_action(self, action_code, game, unit=None, city_tile=None, team=None):
        """
        Takes an action in the environment according to actionCode:
            actionCode: Index of action to take into the action array.
        Returns: An action.
        """
        # Map actionCode index into to a constructed Action object
        try:
            x = None
            y = None
            if city_tile is not None:
                x = city_tile.pos.x
                y = city_tile.pos.y
            elif unit is not None:
                x = unit.pos.x
                y = unit.pos.y
            
            if city_tile != None:
                action =  self.actionSpaceMapCities[action_code%len(self.actionSpaceMapCities)](
                    game=game,
                    unit_id=unit.id if unit else None,
                    unit=unit,
                    city_id=city_tile.city_id if city_tile else None,
                    citytile=city_tile,
                    team=team,
                    x=x,
                    y=y
                )

                # If the city action is invalid, default to research action automatically
                if not action.is_valid(game, actions_validated=[]):
                    action = ResearchAction(
                        game=game,
                        unit_id=unit.id if unit else None,
                        unit=unit,
                        city_id=city_tile.city_id if city_tile else None,
                        citytile=city_tile,
                        team=team,
                        x=x,
                        y=y
                    )
            else:
                action =  self.actionSpaceMapUnits[action_code%len(self.actionSpaceMapUnits)](
                    game=game,
                    unit_id=unit.id if unit else None,
                    unit=unit,
                    city_id=city_tile.city_id if city_tile else None,
                    citytile=city_tile,
                    team=team,
                    x=x,
                    y=y
                )
            
            return action
        except Exception as e:
            # Not a valid action
            print(e)
            return None

    def take_action(self, action_code, game, unit=None, city_tile=None, team=None):
        """
        Takes an action in the environment according to actionCode:
            actionCode: Index of action to take into the action array.
        """
        action = self.action_code_to_action(action_code, game, unit, city_tile, team)
        self.match_controller.take_action(action)
    
    def game_start(self, game):
        """
        This funciton is called at the start of each game. Use this to
        reset and initialize per game. Note that self.team may have
        been changed since last game. The game map has been created
        and starting units placed.

        Args:
            game ([type]): Game.
        """
        self.last_generated_fuel = game.stats["teamStats"][self.team]["fuelGenerated"]
        self.last_resources_collected = copy.deepcopy(game.stats["teamStats"][self.team]["resourcesCollected"])
        if self.stats != None:
            self.stats_last_game =  self.stats
        self.stats = {
            "rew/r_total": 0,
            "rew/r_wood": 0,
            "rew/r_coal": 0,
            "rew/r_uranium": 0,
            "rew/r_research": 0,
            "rew/r_city_tiles_end": 0,
            "rew/r_fuel_collected":0,
            "rew/r_units":0,
            "rew/r_city_tiles":0,
            "rew/r_game_win":0,
            "game/turns": 0,
            "game/reward": 0,
            "game/research": 0,
            "game/unit_count": 0,
            "game/cart_count": 0,
            "game/city_count": 0,
            "game/city_tiles": 0,
            "game/wood_rate_mined": 0,
            "game/coal_rate_mined": 0,
            "game/uranium_rate_mined": 0,
        }
        self.is_last_turn = False

        # Calculate starting map resources
        type_map = {
            Constants.RESOURCE_TYPES.WOOD: "WOOD",
            Constants.RESOURCE_TYPES.COAL: "COAL",
            Constants.RESOURCE_TYPES.URANIUM: "URANIUM",
        }

        self.fuel_collected_last = 0
        self.fuel_start = {}
        self.fuel_last = {}
        for type, type_upper in type_map.items():
            self.fuel_start[type] = 0
            self.fuel_last[type] = 0
            for c in game.map.resources_by_type[type]:
                self.fuel_start[type] += c.resource.amount * game.configs["parameters"]["RESOURCE_TO_FUEL_RATE"][type_upper]

        self.research_last = 0
        self.units_last = 0
        self.city_tiles_last = 0
        self.game_win_last=0

    def get_reward(self, game, is_game_finished, is_new_turn, is_game_error):
        """
        Returns the reward function for this step of the game.
        """
        if is_game_error:
            # Game environment step failed, assign a game lost reward to not incentivise this
            print("Game failed due to error")
            return -1.0

        if not is_new_turn and not is_game_finished:
            # Only apply rewards at the start of each turn
            return 0

        # Get some basic stats
        unit_count = len(game.state["teamStates"][self.team % 2]["units"])
        cart_count = 0
        for id, u in game.state["teamStates"][self.team % 2]["units"].items():
            if u.type == Constants.UNIT_TYPES.CART:
                cart_count += 1

        unit_count_opponent = len(game.state["teamStates"][(self.team + 1) % 2]["units"])
        research = min(game.state["teamStates"][self.team]["researchPoints"], 200.0) # Cap research points at 200
        city_count = 0
        city_count_opponent = 0
        city_tile_count = 0
        city_tile_count_opponent = 0
        for city in game.cities.values():
            if city.team == self.team:
                city_count += 1
            else:
                city_count_opponent += 1

            for cell in city.city_cells:
                if city.team == self.team:
                    city_tile_count += 1
                else:
                    city_tile_count_opponent += 1
        
        # Basic stats
        self.stats["game/research"] = research
        self.stats["game/city_tiles"] = city_tile_count
        self.stats["game/city_count"] = city_count
        self.stats["game/unit_count"] = unit_count
        self.stats["game/cart_count"] = cart_count
        
        self.stats["game/turns"] = game.state["turn"]

        rewards = {}

        # Give up to 1.0 reward for each resource based on % of total mined.
        type_map = {
            Constants.RESOURCE_TYPES.WOOD: "WOOD",
            Constants.RESOURCE_TYPES.COAL: "COAL",
            Constants.RESOURCE_TYPES.URANIUM: "URANIUM",
        }
        fuel_now = {}
        for type, type_upper in type_map.items():
            fuel_now = game.stats["teamStats"][self.team]["resourcesCollected"][type] * game.configs["parameters"]["RESOURCE_TO_FUEL_RATE"][type_upper]
            rewards["rew/r_%s" % type] = (fuel_now - self.fuel_last[type]) / self.fuel_start[type]
            self.stats["game/%s_rate_mined" % type] = fuel_now / self.fuel_start[type]
            self.fuel_last[type] = fuel_now
        
        # Give more incentive for coal and uranium
        rewards["rew/r_%s" % Constants.RESOURCE_TYPES.COAL] *= 2
        rewards["rew/r_%s" % Constants.RESOURCE_TYPES.URANIUM] *= 8
        
        # Give a reward based on amount of fuel collected. 1.0 reward for each 20K fuel gathered.
        fuel_collected = game.stats["teamStats"][self.team]["fuelGenerated"]
        rewards["rew/r_fuel_collected"] = ( (fuel_collected - self.fuel_collected_last) / 20000 )
        self.fuel_collected_last = fuel_collected

        # Give a reward for unit creation/death. 0.05 reward per unit.
        rewards["rew/r_units"] = (unit_count - self.units_last) * 0.05
        self.units_last = unit_count

        # Give a reward for unit creation/death. 0.1 reward per city.
        rewards["rew/r_city_tiles"] = (city_tile_count - self.city_tiles_last) * 0.1
        self.city_tiles_last = city_tile_count

        # Tiny reward for research to help. Up to 0.5 reward for this.
        rewards["rew/r_research"] = (research - self.research_last) / (200 * 2)
        self.research_last = research
        
        # Give a reward up to around 50.0 based on number of city tiles at the end of the game
#         rewards["rew/r_city_tiles_end"] = 0
#         rewards["rew/r_game_win"]=0
        if is_game_finished:
            self.is_last_turn = True
            rewards["rew/r_city_tiles_end"] = city_tile_count
         
            if game.get_winning_team() == self.team:
                game_reward=10
                self.stats["game/reward"]+=game_reward
                
                
                
                rewards["rew/r_game_win"] =  (game_reward-self.game_win_last)
                self.game_win_last=game_reward
               
                
                
                
                
            else:
                game_reward=-10
                self.stats["game/reward"]+=game_reward
                
                
                
                rewards["rew/r_game_win"] =  (game_reward-self.game_win_last)
                self.game_win_last=game_reward
                
                
        
        
        
#         # Update the stats and total reward
        reward = 0
#         total_weighted_reward = 0
#         total_weight = 0
#         weights = {
#         "rew/r_game_win": 0.7,
#         "rew/r_city_tiles_end": 0.5,
#         "rew/r_fuel_collected":0.3,
#         # Add other keys and their weights as needed
        
#     }
#         for key, value in rewards.items():
#           # Default weight for keys not in the weights dictionary
        
#         total_weight += weight
        for name, value in rewards.items():
#             weight = weights.get(name, 0.1)
#             total_weighted_reward += weight * value
#             total_weight += weight
            self.stats[name] +=value
            reward += value
#             if total_weight != 0:
#                 reward = total_weighted_reward / total_weight
#             else:
#                 reward = 0
#         for key,value in rewards.items():
#             self.stats[name] +=((weight * value)/total_weight)
            


            
        self.stats["rew/r_total"] += reward

        # Print the final game stats sometimes
        if is_game_finished and random.random() <= 0.15:
            stats_string = []
            for key, value in self.stats.items():
                stats_string.append("%s=%.2f" % (key, value))
            print(",".join(stats_string))


        return reward
        
    

    def process_turn(self, game, team):
        """
        Decides on a set of actions for the current turn. Not used in training, only inference.
        Returns: Array of actions to perform.
        """
        start_time = time.time()
        actions = []
        new_turn = True

        # Inference the model per-unit
        units = game.state["teamStates"][team]["units"].values()
        for unit in units:
            if unit.can_act():
                obs = self.get_observation(game, unit, None, unit.team, new_turn)
                action_code, _states = self.model.predict(obs, deterministic=False)
                if action_code is not None:
                    actions.append(
                        self.action_code_to_action(action_code, game=game, unit=unit, city_tile=None, team=unit.team))
                new_turn = False

        # Inference the model per-city
        cities = game.cities.values()
        for city in cities:
            if city.team == team:
                for cell in city.city_cells:
                    city_tile = cell.city_tile
                    if city_tile.can_act():
                        obs = self.get_observation(game, None, city_tile, city.team, new_turn)
                        action_code, _states = self.model.predict(obs, deterministic=False)
                        if action_code is not None:
                            actions.append(
                                self.action_code_to_action(action_code, game=game, unit=None, city_tile=city_tile,
                                                           team=city.team))
                        new_turn = False

        time_taken = time.time() - start_time
        if time_taken > 0.5:  # Warn if larger than 0.5 seconds.
            print("WARNING: Inference took %.3f seconds for computing actions. Limit is 1 second." % time_taken,
                  file=sys.stderr)

        return actions
# Out:
# Writing agent_policy.py

# %% [markdown]
# # Build the environment for training
#
# Notes on metrics:
# * An Episode is a single game between your RL agent and it's opponent. This is generally 360 turns, spanning more than 360 unit + city decision steps.
# * Mean episode length (ep_len_mean) is the number of decision made per game. The larger this gets, means that it is making more unit + city decision per game, meaning that more units and cities were alive for longer during the game.
# * Episode reward mean (ep_rew_mean), is set up as micro-reward funciton for faster learning. Per turn it gets a small reward based on the number of cities and units alive. It gets a really big reward based on the number of cities and units alive at the end of the game.

# %%
pip install stable-baselines3

# %%
import argparse
import glob
import os
import random
from typing import Callable

from stable_baselines3 import PPO  # pip install stable-baselines3
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.vec_env import SubprocVecEnv

from importlib import reload
import agent_policy
reload(agent_policy) # Reload the file from disk incase the above agent-writing cell block was edited
from agent_policy import AgentPolicy

from luxai2021.env.agent import Agent
from luxai2021.env.lux_env import LuxEnvironment
from luxai2021.game.constants import LuxMatchConfigs_Default


# Default Lux configs
configs = LuxMatchConfigs_Default

# Create a default opponent agent
opponent = Agent()

# Create a RL agent in training mode
player = AgentPolicy(mode="train")

# Create the Lux environment
env = LuxEnvironment(configs=configs,
                     learning_agent=player,
                     opponent_agent=opponent)

# Define the model, you can pick other RL algos from Stable Baselines3 instead if you like
model = PPO("MlpPolicy",
                env,
                verbose=1,
                tensorboard_log="./lux_tensorboard/",
                learning_rate=0.001,
                gamma=0.999,
                gae_lambda=0.95,
                batch_size=2048 * 8,
                n_steps=2048 * 8
            )

# Define a learning rate schedule
# (number of steps, learning_rate)
schedule = [
    #(2000000, 0.01),
    (6000000, 0.001),
    (6000000, 0.0001),
]
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Running in inference-only mode.

# %% [markdown]
# # Train the agent against a dummy opponent

# %%
from stable_baselines3.common.utils import get_schedule_fn

print("Training model...")
run_id = 1

# Save a checkpoint every 1M steps
checkpoint_callback = CheckpointCallback(save_freq=1000000,
                                         save_path='./models/',
                                         name_prefix=f'rl_model_{run_id}')

# Train the policy
for steps, learning_rate in schedule:
    model.lr_schedule = get_schedule_fn(learning_rate)
    model.learn(total_timesteps=steps,
                callback=checkpoint_callback,
                reset_num_timesteps = False)

# Save final model
model.save(path=f'models/model.zip')

print("Done training model.")
# Out:
# Training model...
# Logging to ./lux_tensorboard/PPO_0
# rew/r_total=-9.96,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=116.00,game/reward=-10.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.98,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=32.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.99,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=31.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=11.60,rew/r_wood=0.33,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.07,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.05,rew/r_units=0.05,rew/r_city_tiles=0.10,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=26.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.33,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.93,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=72.00,game/reward=-10.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.97,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=38.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.93,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=71.00,game/reward=-10.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.91,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=196.00,game/reward=-10.00,game/research=13.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.92,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=111.00,game/reward=-10.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=10.13,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.00,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=8.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.98,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=31.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.76,rew/r_wood=0.14,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.07,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=271.00,game/reward=-10.00,game/research=29.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.14,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.93,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=157.00,game/reward=-10.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.98,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=71.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.96,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=116.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=10.32,rew/r_wood=0.17,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.07,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.04,rew/r_units=0.05,rew/r_city_tiles=0.00,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=26.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.17,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.97,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=111.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.87,rew/r_wood=0.08,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=156.00,game/reward=-10.00,game/research=13.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.08,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.96,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=196.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.93,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=111.00,game/reward=-10.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.86,rew/r_wood=0.11,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=231.00,game/reward=-10.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.11,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.96,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=34.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.3     |
# |    ep_rew_mean     | -8.49    |
# | time/              |          |
# |    fps             | 306      |
# |    iterations      | 1        |
# |    time_elapsed    | 53       |
# |    total_timesteps | 16384    |
# ---------------------------------
# rew/r_total=-9.94,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=112.00,game/reward=-10.00,game/research=10.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.92,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=71.00,game/reward=-10.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.97,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=32.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.93,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=78.00,game/reward=-10.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.87,rew/r_wood=0.10,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=152.00,game/reward=-10.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.10,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.92,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=111.00,game/reward=-10.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.87,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.05,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=360.00,game/reward=-10.00,game/research=13.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.85,rew/r_wood=0.11,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=351.00,game/reward=-10.00,game/research=12.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.11,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.94,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=71.00,game/reward=-10.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.99,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=31.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.96,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=71.00,game/reward=-10.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.90,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=113.00,game/reward=-10.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.91,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=151.00,game/reward=-10.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.96,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=73.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.98,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=152.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.81,rew/r_wood=0.09,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.07,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=312.00,game/reward=-10.00,game/research=28.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.09,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=10.27,rew/r_wood=0.15,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.06,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.05,rew/r_city_tiles=0.00,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=23.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.15,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.94,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=196.00,game/reward=-10.00,game/research=10.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.92,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=111.00,game/reward=-10.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.84,rew/r_wood=0.11,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=191.00,game/reward=-10.00,game/research=16.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.11,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -8.64       |
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 2           |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006077074 |
# |    clip_fraction        | 0.000739    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.0227     |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.9         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00224    |
# |    value_loss           | 8.44        |
# -----------------------------------------
# rew/r_total=-9.96,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=35.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.97,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=37.00,game/reward=-10.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.98,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=118.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.98,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=31.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.97,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=71.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.97,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=191.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.93,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=191.00,game/reward=-10.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.98,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=116.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=10.12,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.05,rew/r_city_tiles=0.00,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=9.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.93,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=116.00,game/reward=-10.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.96,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=116.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=12.99,rew/r_wood=0.49,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.13,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.07,rew/r_units=0.10,rew/r_city_tiles=0.20,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=52.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=2.00,game/wood_rate_mined=0.49,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.97,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=111.00,game/reward=-10.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.98,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=36.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.99,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=32.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=10.13,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.05,rew/r_city_tiles=0.00,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=10.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.92,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=196.00,game/reward=-10.00,game/research=13.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.87,rew/r_wood=0.10,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=271.00,game/reward=-10.00,game/research=10.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.10,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.99,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=31.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.88,rew/r_wood=0.10,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=274.00,game/reward=-10.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.10,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.72,rew/r_wood=0.22,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=151.00,game/reward=-10.00,game/research=18.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.22,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.95,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=75.00,game/reward=-10.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.92,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=111.00,game/reward=-10.00,game/research=12.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.97,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=39.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.91,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=115.00,game/reward=-10.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.85,rew/r_wood=0.10,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=231.00,game/reward=-10.00,game/research=17.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.10,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.90,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=116.00,game/reward=-10.00,game/research=12.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.94,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=154.00,game/reward=-10.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.92,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=111.00,game/reward=-10.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | -8.45       |
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 3           |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005808707 |
# |    clip_fraction        | 0.00149     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.0332      |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.65        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00107    |
# |    value_loss           | 5.9         |
# -----------------------------------------
# rew/r_total=-9.95,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=111.00,game/reward=-10.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.90,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=78.00,game/reward=-10.00,game/research=10.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.92,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=80.00,game/reward=-10.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.77,rew/r_wood=0.16,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.07,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=231.00,game/reward=-10.00,game/research=26.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.16,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.98,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=32.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.99,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=31.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.91,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=111.00,game/reward=-10.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.97,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=39.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.96,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=39.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.95,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=271.00,game/reward=-10.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=10.09,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.00,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=4.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.94,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=112.00,game/reward=-10.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.95,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=71.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.95,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=35.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=15.70,rew/r_wood=0.80,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.18,rew/r_city_tiles_end=4.00,rew/r_fuel_collected=0.12,rew/r_units=0.20,rew/r_city_tiles=0.40,rew/r_game_win=10.00,game/turns=359.00,game/reward=10.00,game/research=71.00,game/unit_count=4.00,game/cart_count=1.00,game/city_count=4.00,game/city_tiles=4.00,game/wood_rate_mined=0.80,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.96,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=71.00,game/reward=-10.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.95,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=157.00,game/reward=-10.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.98,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=31.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.96,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=71.00,game/reward=-10.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.98,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=71.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.95,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=38.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.96,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=111.00,game/reward=-10.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.97,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=71.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.95,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=151.00,game/reward=-10.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.69,rew/r_wood=0.22,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.06,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=191.00,game/reward=-10.00,game/research=23.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.22,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.97,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=116.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.82,rew/r_wood=0.13,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=119.00,game/reward=-10.00,game/research=13.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.13,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.97,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=116.00,game/reward=-10.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.92,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=158.00,game/reward=-10.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.86,rew/r_wood=0.11,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=196.00,game/reward=-10.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.11,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99.5         |
# |    ep_rew_mean          | -7.84        |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 4            |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0074679144 |
# |    clip_fraction        | 0.00707      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.0643       |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.86         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 5.94         |
# ------------------------------------------
# rew/r_total=-9.68,rew/r_wood=0.22,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.07,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=160.00,game/reward=-10.00,game/research=28.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.22,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=10.08,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.00,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=4.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.96,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=116.00,game/reward=-10.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.96,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=151.00,game/reward=-10.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=-9.90,rew/r_wood=0.08,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,rew/r_game_win=-10.00,game/turns=320.00,game/reward=-10.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.08,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ...
# |    ep_rew_mean          | 17.2         |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 252          |
# |    time_elapsed         | 10840        |
# |    total_timesteps      | 4128768      |
# | train/                  |              |
# |    approx_kl            | 0.0020825306 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.546       |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.189        |
# |    n_updates            | 2510         |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 0.396        |
# ------------------------------------------
# rew/r_total=18.34,rew/r_wood=1.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.16,rew/r_city_tiles_end=6.00,rew/r_fuel_collected=0.26,rew/r_units=0.30,rew/r_city_tiles=0.60,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=64.00,game/unit_count=6.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=6.00,game/wood_rate_mined=1.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=11.84,rew/r_wood=0.37,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.27,rew/r_units=0.05,rew/r_city_tiles=0.10,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=20.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.37,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=12.16,rew/r_wood=0.69,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.27,rew/r_units=0.05,rew/r_city_tiles=0.10,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=20.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.69,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=14.04,rew/r_wood=0.26,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.10,rew/r_city_tiles_end=3.00,rew/r_fuel_collected=0.28,rew/r_units=0.10,rew/r_city_tiles=0.30,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=41.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=3.00,game/wood_rate_mined=0.26,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 626         |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 253         |
# |    time_elapsed         | 10879       |
# |    total_timesteps      | 4145152     |
# | train/                  |             |
# |    approx_kl            | 0.003034478 |
# |    clip_fraction        | 0.031       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.55       |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.15        |
# |    n_updates            | 2520        |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 0.319       |
# -----------------------------------------
# rew/r_total=21.51,rew/r_wood=0.75,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.15,rew/r_city_tiles_end=9.00,rew/r_fuel_collected=0.26,rew/r_units=0.45,rew/r_city_tiles=0.90,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=59.00,game/unit_count=9.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=9.00,game/wood_rate_mined=0.75,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=34.88,rew/r_wood=2.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.47,rew/r_city_tiles_end=19.00,rew/r_fuel_collected=0.50,rew/r_units=0.95,rew/r_city_tiles=1.90,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=186.00,game/unit_count=19.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=19.00,game/wood_rate_mined=2.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=11.92,rew/r_wood=0.43,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.29,rew/r_units=0.05,rew/r_city_tiles=0.10,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=20.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.43,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 625          |
# |    ep_rew_mean          | 17.5         |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 254          |
# |    time_elapsed         | 10917        |
# |    total_timesteps      | 4161536      |
# | train/                  |              |
# |    approx_kl            | 0.0021408033 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.444       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.12         |
# |    n_updates            | 2530         |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 0.257        |
# ------------------------------------------
# rew/r_total=-8.91,rew/r_wood=0.61,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.33,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.14,rew/r_units=-0.00,rew/r_city_tiles=-0.00,rew/r_game_win=-10.00,game/turns=357.00,game/reward=-10.00,game/research=132.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.61,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=13.81,rew/r_wood=0.93,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.13,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.46,rew/r_units=0.10,rew/r_city_tiles=0.20,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=53.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=2.00,game/wood_rate_mined=0.93,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 712          |
# |    ep_rew_mean          | 17.9         |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 255          |
# |    time_elapsed         | 10951        |
# |    total_timesteps      | 4177920      |
# | train/                  |              |
# |    approx_kl            | 0.0020695634 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.487       |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.144        |
# |    n_updates            | 2540         |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 0.311        |
# ------------------------------------------
# rew/r_total=12.44,rew/r_wood=0.54,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.49,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.26,rew/r_units=0.05,rew/r_city_tiles=0.10,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=195.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.54,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=12.09,rew/r_wood=0.61,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.28,rew/r_units=0.05,rew/r_city_tiles=0.10,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=20.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.61,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=17.52,rew/r_wood=1.06,rew/r_coal=0.26,rew/r_uranium=0.00,rew/r_research=0.22,rew/r_city_tiles_end=5.00,rew/r_fuel_collected=0.28,rew/r_units=0.20,rew/r_city_tiles=0.50,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=88.00,game/unit_count=4.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=5.00,game/wood_rate_mined=1.06,game/coal_rate_mined=0.13,game/uranium_rate_mined=0.00
# rew/r_total=21.86,rew/r_wood=0.94,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.38,rew/r_city_tiles_end=9.00,rew/r_fuel_collected=0.24,rew/r_units=0.40,rew/r_city_tiles=0.90,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=152.00,game/unit_count=8.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=9.00,game/wood_rate_mined=0.94,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=16.35,rew/r_wood=0.35,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.13,rew/r_city_tiles_end=5.00,rew/r_fuel_collected=0.22,rew/r_units=0.15,rew/r_city_tiles=0.50,rew/r_game_win=10.00,game/turns=312.00,game/reward=10.00,game/research=53.00,game/unit_count=3.00,game/cart_count=0.00,game/city_count=4.00,game/city_tiles=5.00,game/wood_rate_mined=0.35,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 700          |
# |    ep_rew_mean          | 17.7         |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 256          |
# |    time_elapsed         | 10986        |
# |    total_timesteps      | 4194304      |
# | train/                  |              |
# |    approx_kl            | 0.0014173508 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.492       |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.362        |
# |    n_updates            | 2550         |
# |    policy_gradient_loss | -0.000659    |
# |    value_loss           | 0.759        |
# ------------------------------------------
# rew/r_total=25.67,rew/r_wood=1.42,rew/r_coal=0.80,rew/r_uranium=0.01,rew/r_research=0.50,rew/r_city_tiles_end=11.00,rew/r_fuel_collected=0.30,rew/r_units=0.55,rew/r_city_tiles=1.10,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=200.00,game/unit_count=11.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=11.00,game/wood_rate_mined=1.42,game/coal_rate_mined=0.40,game/uranium_rate_mined=0.00
# rew/r_total=13.01,rew/r_wood=0.36,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.09,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.26,rew/r_units=0.10,rew/r_city_tiles=0.20,rew/r_game_win=10.00,game/turns=315.00,game/reward=10.00,game/research=34.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=2.00,game/wood_rate_mined=0.36,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 714          |
# |    ep_rew_mean          | 17.5         |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 257          |
# |    time_elapsed         | 11023        |
# |    total_timesteps      | 4210688      |
# | train/                  |              |
# |    approx_kl            | 0.0035013584 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.529       |
# |    explained_variance   | 0.898        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.17         |
# |    n_updates            | 2560         |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 0.359        |
# ------------------------------------------
# rew/r_total=34.64,rew/r_wood=1.79,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=19.00,rew/r_fuel_collected=0.44,rew/r_units=1.00,rew/r_city_tiles=1.90,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=200.00,game/unit_count=20.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=19.00,game/wood_rate_mined=1.79,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 751          |
# |    ep_rew_mean          | 17.8         |
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 258          |
# |    time_elapsed         | 11060        |
# |    total_timesteps      | 4227072      |
# | train/                  |              |
# |    approx_kl            | 0.0011539038 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.438       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.119        |
# |    n_updates            | 2570         |
# |    policy_gradient_loss | -0.000909    |
# |    value_loss           | 0.263        |
# ------------------------------------------
# rew/r_total=28.23,rew/r_wood=2.42,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.33,rew/r_city_tiles_end=13.00,rew/r_fuel_collected=0.54,rew/r_units=0.65,rew/r_city_tiles=1.30,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=130.00,game/unit_count=13.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=13.00,game/wood_rate_mined=2.42,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=12.30,rew/r_wood=0.83,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.27,rew/r_units=0.05,rew/r_city_tiles=0.10,rew/r_game_win=10.00,game/turns=198.00,game/reward=10.00,game/research=20.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.83,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 672          |
# |    ep_rew_mean          | 17.4         |
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 259          |
# |    time_elapsed         | 11099        |
# |    total_timesteps      | 4243456      |
# | train/                  |              |
# |    approx_kl            | 0.0027652828 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.554       |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.102        |
# |    n_updates            | 2580         |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 0.224        |
# ------------------------------------------
# rew/r_total=23.59,rew/r_wood=1.60,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.16,rew/r_city_tiles_end=10.00,rew/r_fuel_collected=0.33,rew/r_units=0.50,rew/r_city_tiles=1.00,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=65.00,game/unit_count=10.00,game/cart_count=0.00,game/city_count=4.00,game/city_tiles=10.00,game/wood_rate_mined=1.60,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=20.12,rew/r_wood=0.46,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.21,rew/r_city_tiles_end=8.00,rew/r_fuel_collected=0.30,rew/r_units=0.35,rew/r_city_tiles=0.80,rew/r_game_win=10.00,game/turns=360.00,game/reward=10.00,game/research=85.00,game/unit_count=7.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=8.00,game/wood_rate_mined=0.46,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00

# %%
# Learn with self-play against the learned model as an opponent now
print("Training model with self-play against last version of model...")
player = AgentPolicy(mode="train")
opponent = AgentPolicy(mode="inference", model=model)
env = LuxEnvironment(configs, player, opponent)
model = PPO("MlpPolicy",
    env,
    verbose=1,
    tensorboard_log="./lux_tensorboard/",
    learning_rate = 0.00001,
    gamma=0.995,
    gae_lambda = 0.95
)

model.learn(total_timesteps=5000)
model.save(path=f'models/self_learn_model.zip')
print("Done")

# %%
# Save final model
model.save(path=f'models/model.zip')

print("Done training model.")

# %% [markdown]
# # Set up a Kaggle Submission and lux replay environment for the agent

# %%
"""
This downloads two required python package dependencies that are not pre-installed
by Kaggle yet.

This places the following two packages in the current working directory:
    luxai2021
    stable_baselines3
"""

import os
import shutil
import subprocess
import tempfile

def localize_package(git, branch, folder):
    if os.path.exists(folder):
        print("Already localized %s" % folder)
    else:
        # https://stackoverflow.com/questions/51239168/how-to-download-single-file-from-a-git-repository-using-python
        # Create temporary dir
        t = tempfile.mkdtemp()

        args = ['git', 'clone', '--depth=1', git, t, '-b', branch]
        res = subprocess.Popen(args, stdout=subprocess.PIPE)
        output, _error = res.communicate()

        if not _error:
            print(output)
        else:
            print(_error)
        
        # Copy desired file from temporary dir
        shutil.move(os.path.join(t, folder), '.')
        # Remove temporary dir
        shutil.rmtree(t, ignore_errors=True)

localize_package('https://github.com/glmcdona/LuxPythonEnvGym.git', 'main', 'luxai2021')
localize_package('https://github.com/glmcdona/LuxPythonEnvGym.git', 'main', 'kaggle_submissions')
localize_package('https://github.com/DLR-RM/stable-baselines3.git', 'master', 'stable_baselines3')

# %%
# Move the dependent packages into kaggle submissions
# !mv luxai2021 kaggle_submissions
# !mv stable_baselines3 kaggle_submissions
# !rm ./kaggle_submissions/agent_policy.py
# !cp agent_policy.py kaggle_submissions

# Copy the agent and model to the submission 
# !cp ./agent_policy.py kaggle_submissions
# !cp ./models/model.zip kaggle_submissions

# !ls kaggle_submissions

# %%
from kaggle_environments import make
import json
# run another match but with our empty agent
env = make("lux_ai_2021", configuration={"seed": 5621242, "loglevel": 2, "annotations": True}, debug=True)

# Play the environment where the RL agent plays against itself
steps = env.run(["./kaggle_submissions/main.py", "./kaggle_submissions/main.py"])

# %%
# Render the match
env.render(mode="ipython", width=1200, height=800)

# %% [markdown]
# # Prepare and submit the kaggle submission

# %%
# !tar -czf submission.tar.gz -C kaggle_submissions .
# !ls
