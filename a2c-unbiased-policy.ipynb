# %% [markdown]
# # Lux AI Deep Reinforcement Learning Environment Example
# See https://github.com/glmcdona/LuxPythonEnvGym for environment project and updates.
#
# This is a python replica of the Lux game engine to speed up training. It reformats the agent problem into making a action decision per-unit for the team.

# %%
# !pip install git+https://github.com/glmcdona/LuxPythonEnvGym.git
# !pip install kaggle-environments -U
# Out:
# Collecting git+https://github.com/glmcdona/LuxPythonEnvGym.git
#   Cloning https://github.com/glmcdona/LuxPythonEnvGym.git to /tmp/pip-req-build-9pw7tmoq
#   Running command git clone -q https://github.com/glmcdona/LuxPythonEnvGym.git /tmp/pip-req-build-9pw7tmoq
# Requirement already satisfied: pytest in /opt/conda/lib/python3.7/site-packages (from luxai2021==0.1.0) (6.2.4)
# Collecting stable_baselines3==1.2.1a2
#   Downloading stable_baselines3-1.2.1a2-py3-none-any.whl (173 kB)
#      |████████████████████████████████| 173 kB 4.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from luxai2021==0.1.0) (1.19.5)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.7/site-packages (from luxai2021==0.1.0) (2.4.1)
# Collecting gym==0.19.0
#   Downloading gym-0.19.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 44.8 MB/s eta 0:00:01
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from gym==0.19.0->luxai2021==0.1.0) (1.6.0)
# Collecting torch>=1.8.1
#   Downloading torch-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (887.5 MB)
#      |████████████████████████████████| 887.5 MB 6.1 kB/s  eta 0:00:014   |▌                               | 13.9 MB 37.1 MB/s eta 0:00:24
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from stable_baselines3==1.2.1a2->luxai2021==0.1.0) (3.4.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from stable_baselines3==1.2.1a2->luxai2021==0.1.0) (1.2.4)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      |████████████████████████████████| 849 kB 47.9 MB/s eta 0:00:01
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 52.6 MB/s eta 0:00:01
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      |████████████████████████████████| 557.1 MB 7.9 kB/s  eta 0:00:01
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.7/site-packages (from torch>=1.8.1->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (3.7.4.3)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      |████████████████████████████████| 317.1 MB 55.1 MB/s eta 0:00:01     |████████████████████████████████| 317.1 MB 24 kB/s
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.1->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (49.6.0.post20210108)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.1->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (0.36.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (8.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (1.3.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->stable_baselines3==1.2.1a2->luxai2021==0.1.0) (2021.1)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (1.1.1)
# Requirement already satisfied: importlib-metadata>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (3.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (21.2.0)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (1.10.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (20.9)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (0.13.1)
# Requirement already satisfied: toml in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (0.10.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->luxai2021==0.1.0) (3.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (2.25.1)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (0.12.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (1.8.0)
# Requirement already satisfied: protobuf>=3.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (3.17.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (1.30.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (2.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (0.4.4)
# Requirement already satisfied: grpcio>=1.24.3 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (1.32.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard->luxai2021==0.1.0) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard->luxai2021==0.1.0) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard->luxai2021==0.1.0) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->luxai2021==0.1.0) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard->luxai2021==0.1.0) (0.4.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->luxai2021==0.1.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->luxai2021==0.1.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->luxai2021==0.1.0) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->luxai2021==0.1.0) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->luxai2021==0.1.0) (3.1.1)
# Building wheels for collected packages: luxai2021, gym
#   Building wheel for luxai2021 (setup.py) ... done
#   Created wheel for luxai2021: filename=luxai2021-0.1.0-py3-none-any.whl size=46730 sha256=7faa762807d64d75e5d39ded47162713a3df3688716b6df45c2aaa3d4e5da541
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f2518m11/wheels/b2/22/ee/884dd4091817cdc45e2980f439823344fb99cad2a54fa05e65
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.19.0-py3-none-any.whl size=1663121 sha256=321268279becb1dc91d55a302e322a1018310f3e8888388a5bf775401d01715c
#   Stored in directory: /root/.cache/pip/wheels/ef/9d/70/8bea53f7edec2fdb4f98d9d64ac9f11aea95dfcb98099d7712
# Successfully built luxai2021 gym
# Installing collected packages: nvidia-cublas-cu11, nvidia-cudnn-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, torch, gym, stable-baselines3, luxai2021
#   Attempting uninstall: torch
#     Found existing installation: torch 1.7.0
#     Uninstalling torch-1.7.0:
#       Successfully uninstalled torch-1.7.0
#   Attempting uninstall: gym
#     Found existing installation: gym 0.18.3
#     Uninstalling gym-0.18.3:
#       Successfully uninstalled gym-0.18.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kornia 0.5.5 requires numpy<=1.19, but you have numpy 1.19.5 which is incompatible.
# fastai 2.2.7 requires torch<1.8,>=1.7.0, but you have torch 1.13.1 which is incompatible.
# allennlp 2.5.0 requires torch<1.9.0,>=1.6.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed gym-0.19.0 luxai2021-0.1.0 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 stable-baselines3-1.2.1a2 torch-1.13.1
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Requirement already satisfied: kaggle-environments in /opt/conda/lib/python3.7/site-packages (1.7.11)
# Collecting kaggle-environments
#   Downloading kaggle_environments-1.14.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 4.4 MB/s eta 0:00:01
# Collecting vec-noise>=1.1.4
#   Downloading vec_noise-1.1.4.zip (134 kB)
#      |████████████████████████████████| 134 kB 48.5 MB/s eta 0:00:01
# Collecting pickle5==0.0.12
#   Downloading pickle5-0.0.12-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (256 kB)
#      |████████████████████████████████| 256 kB 53.5 MB/s eta 0:00:01
# Collecting PettingZoo==1.12.0
#   Downloading PettingZoo-1.12.0.tar.gz (756 kB)
#      |████████████████████████████████| 756 kB 52.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.19.5 in /opt/conda/lib/python3.7/site-packages (from kaggle-environments) (1.19.5)
# Requirement already satisfied: Flask>=1.1.2 in /opt/conda/lib/python3.7/site-packages (from kaggle-environments) (2.0.1)
# Requirement already satisfied: requests>=2.25.1 in /opt/conda/lib/python3.7/site-packages (from kaggle-environments) (2.25.1)
# Collecting gym==0.21.0
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      |████████████████████████████████| 1.5 MB 41.7 MB/s eta 0:00:01
# Collecting stable-baselines3==1.7.0
#   Downloading stable_baselines3-1.7.0-py3-none-any.whl (171 kB)
#      |████████████████████████████████| 171 kB 42.0 MB/s eta 0:00:01
# Requirement already satisfied: jsonschema>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from kaggle-environments) (3.2.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from gym==0.21.0->kaggle-environments) (1.6.0)
# Collecting importlib_metadata>=4.8.1
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from stable-baselines3==1.7.0->kaggle-environments) (1.2.4)
# Collecting typing-extensions<5,>=4.0
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from stable-baselines3==1.7.0->kaggle-environments) (3.4.2)
# Collecting importlib_metadata>=4.8.1
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: torch>=1.11 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3==1.7.0->kaggle-environments) (1.13.1)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/conda/lib/python3.7/site-packages (from Flask>=1.1.2->kaggle-environments) (2.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /opt/conda/lib/python3.7/site-packages (from Flask>=1.1.2->kaggle-environments) (3.0.1)
# Requirement already satisfied: click>=7.1.2 in /opt/conda/lib/python3.7/site-packages (from Flask>=1.1.2->kaggle-environments) (7.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in /opt/conda/lib/python3.7/site-packages (from Flask>=1.1.2->kaggle-environments) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib_metadata>=4.8.1->gym==0.21.0->kaggle-environments) (3.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.7/site-packages (from Jinja2>=3.0->Flask>=1.1.2->kaggle-environments) (2.0.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (49.6.0.post20210108)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.25.1->kaggle-environments) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.25.1->kaggle-environments) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=2.25.1->kaggle-environments) (1.26.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.25.1->kaggle-environments) (4.0.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3==1.7.0->kaggle-environments) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3==1.7.0->kaggle-environments) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3==1.7.0->kaggle-environments) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3==1.7.0->kaggle-environments) (11.7.99)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11->stable-baselines3==1.7.0->kaggle-environments) (0.36.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3==1.7.0->kaggle-environments) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3==1.7.0->kaggle-environments) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3==1.7.0->kaggle-environments) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3==1.7.0->kaggle-environments) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3==1.7.0->kaggle-environments) (1.3.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->stable-baselines3==1.7.0->kaggle-environments) (2021.1)
# Building wheels for collected packages: gym, PettingZoo, vec-noise
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616826 sha256=a45a313decde403528bd76c7c91b11cdebc1bf22097098a2f442ebbe44e6ca65
#   Stored in directory: /root/.cache/pip/wheels/76/ee/9c/36bfe3e079df99acf5ae57f4e3464ff2771b34447d6d2f2148
#   Building wheel for PettingZoo (setup.py) ... done
#   Created wheel for PettingZoo: filename=PettingZoo-1.12.0-py3-none-any.whl size=873565 sha256=873b531c48147d1c0f4698458b011009adffc8c1a76e526a92ea1c9bc13bf9bf
#   Stored in directory: /root/.cache/pip/wheels/50/1d/da/6a09fdb8c06333aa981d1239e40cc8aa5cbac80b30498b1e85
#   Building wheel for vec-noise (setup.py) ... done
#   Created wheel for vec-noise: filename=vec_noise-1.1.4-cp37-cp37m-linux_x86_64.whl size=86387 sha256=652128f685c2866ef04a9f5afbc15e8a52a38dc8892584f62aaf472084e0afb7
#   Stored in directory: /root/.cache/pip/wheels/fc/0c/19/5932b4834cf3204ed2ae845e788f07c79b3279c302d55d6fa8
# Successfully built gym PettingZoo vec-noise
# Installing collected packages: typing-extensions, importlib-metadata, gym, vec-noise, stable-baselines3, pickle5, PettingZoo, kaggle-environments
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.4.0
#     Uninstalling importlib-metadata-3.4.0:
#       Successfully uninstalled importlib-metadata-3.4.0
#   Attempting uninstall: gym
#     Found existing installation: gym 0.19.0
#     Uninstalling gym-0.19.0:
#       Successfully uninstalled gym-0.19.0
#   Attempting uninstall: stable-baselines3
#     Found existing installation: stable-baselines3 1.2.1a2
#     Uninstalling stable-baselines3-1.2.1a2:
#       Successfully uninstalled stable-baselines3-1.2.1a2
#   Attempting uninstall: kaggle-environments
#     Found existing installation: kaggle-environments 1.7.11
#     Uninstalling kaggle-environments-1.7.11:
#       Successfully uninstalled kaggle-environments-1.7.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.4.1 requires typing-extensions~=3.7.4, but you have typing-extensions 4.7.1 which is incompatible.
# luxai2021 0.1.0 requires gym==0.19.0, but you have gym 0.21.0 which is incompatible.
# luxai2021 0.1.0 requires stable-baselines3==1.2.1a2, but you have stable-baselines3 1.7.0 which is incompatible.
# kornia 0.5.5 requires numpy<=1.19, but you have numpy 1.19.5 which is incompatible.
# fastai 2.2.7 requires torch<1.8,>=1.7.0, but you have torch 1.13.1 which is incompatible.
# arviz 0.11.2 requires typing-extensions<4,>=3.7.4.3, but you have typing-extensions 4.7.1 which is incompatible.
# allennlp 2.5.0 requires torch<1.9.0,>=1.6.0, but you have torch 1.13.1 which is incompatible.
# aiobotocore 1.3.1 requires botocore<1.20.50,>=1.20.49, but you have botocore 1.20.105 which is incompatible.
# Successfully installed PettingZoo-1.12.0 gym-0.21.0 importlib-metadata-4.13.0 kaggle-environments-1.14.0 pickle5-0.0.12 stable-baselines3-1.7.0 typing-extensions-4.7.1 vec-noise-1.1.4
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %% [markdown]
# ## Use GPU if available
# Note: GPU provides very little speedup. I recommend using a CPU-only notebook usually.

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
print(device)
# Out:
# cpu

# %% [markdown]
# # Define the RL agent logic
# Edit this agent logic to implement your own observations, action space, and reward shaping.

# %%
# %%writefile agent_policy.py
from luxai2021.game.match_controller import ActionSequence
import sys
import time
from functools import partial  # pip install functools

import numpy as np
from gym import spaces
import copy
import random

from luxai2021.env.agent import Agent
from luxai2021.game.actions import *
from luxai2021.game.game_constants import GAME_CONSTANTS
from luxai2021.game.position import Position


# https://codereview.stackexchange.com/questions/28207/finding-the-closest-point-to-a-list-of-points
def closest_node(node, nodes):
    dist_2 = np.sum((nodes - node) ** 2, axis=1)
    return np.argmin(dist_2)
def furthest_node(node, nodes):
    dist_2 = np.sum((nodes - node) ** 2, axis=1)
    return np.argmax(dist_2)

def smart_transfer_to_nearby(game, team, unit_id, unit, target_type_restriction=None, **kwarg):
    """
    Smart-transfers from the specified unit to a nearby neighbor. Prioritizes any
    nearby carts first, then any worker. Transfers the resource type which the unit
    has most of. Picks which cart/worker based on choosing a target that is most-full
    but able to take the most amount of resources.

    Args:
        team ([type]): [description]
        unit_id ([type]): [description]

    Returns:
        Action: Returns a TransferAction object, even if the request is an invalid
                transfer. Use TransferAction.is_valid() to check validity.
    """

    # Calculate how much resources could at-most be transferred
    resource_type = None
    resource_amount = 0
    target_unit = None

    if unit != None:
        for type, amount in unit.cargo.items():
            if amount > resource_amount:
                resource_type = type
                resource_amount = amount

        # Find the best nearby unit to transfer to
        unit_cell = game.map.get_cell_by_pos(unit.pos)
        adjacent_cells = game.map.get_adjacent_cells(unit_cell)

        
        for c in adjacent_cells:
            for id, u in c.units.items():
                # Apply the unit type target restriction
                if target_type_restriction == None or u.type == target_type_restriction:
                    if u.team == team:
                        # This unit belongs to our team, set it as the winning transfer target
                        # if it's the best match.
                        if target_unit is None:
                            target_unit = u
                        else:
                            # Compare this unit to the existing target
                            if target_unit.type == u.type:
                                # Transfer to the target with the least capacity, but can accept
                                # all of our resources
                                if( u.get_cargo_space_left() >= resource_amount and 
                                    target_unit.get_cargo_space_left() >= resource_amount ):
                                    # Both units can accept all our resources. Prioritize one that is most-full.
                                    if u.get_cargo_space_left() < target_unit.get_cargo_space_left():
                                        # This new target it better, it has less space left and can take all our
                                        # resources
                                        target_unit = u
                                    
                                elif( target_unit.get_cargo_space_left() >= resource_amount ):
                                    # Don't change targets. Current one is best since it can take all
                                    # the resources, but new target can't.
                                    pass
                                    
                                elif( u.get_cargo_space_left() > target_unit.get_cargo_space_left() ):
                                    # Change targets, because neither target can accept all our resources and 
                                    # this target can take more resources.
                                    target_unit = u
                            elif u.type == Constants.UNIT_TYPES.CART:
                                # Transfer to this cart instead of the current worker target
                                target_unit = u
    
    # Build the transfer action request
    target_unit_id = None
    if target_unit is not None:
        target_unit_id = target_unit.id

        # Update the transfer amount based on the room of the target
        if target_unit.get_cargo_space_left() < resource_amount:
            resource_amount = target_unit.get_cargo_space_left()
    
    return TransferAction(team, unit_id, target_unit_id, resource_type, resource_amount)

########################################################################################################################
# This is the Agent that you need to design for the competition
########################################################################################################################
class AgentPolicy(Agent):
    def __init__(self, mode="train", model=None) -> None:
        """
        Arguments:
            mode: "train" or "inference", which controls if this agent is for training or not.
            model: The pretrained model, or if None it will operate in training mode.
        """
        super().__init__()
        self.model = model
        self.mode = mode
        
        self.stats = None
        self.stats_last_game = None

        # Define action and observation space
        # They must be gym.spaces objects
        # Example when using discrete actions:
        self.actionSpaceMapUnits = [
            partial(MoveAction, direction=Constants.DIRECTIONS.CENTER),  # This is the do-nothing action
            partial(MoveAction, direction=Constants.DIRECTIONS.NORTH),
            partial(MoveAction, direction=Constants.DIRECTIONS.WEST),
            partial(MoveAction, direction=Constants.DIRECTIONS.SOUTH),
            partial(MoveAction, direction=Constants.DIRECTIONS.EAST),
            smart_transfer_to_nearby, # Transfer to nearby
            SpawnCityAction,
            #PillageAction,
        ]
        self.actionSpaceMapCities = [
            SpawnWorkerAction,
            SpawnCartAction,
            ResearchAction,
        ]

        self.action_space = spaces.Discrete(max(len(self.actionSpaceMapUnits), len(self.actionSpaceMapCities)))
        

        # Observation space: (Basic minimum for a miner agent)
        # Object:
        #   1x is worker
        #   1x is cart
        #   1x is citytile
        #
        #   5x direction_nearest_wood
        #   1x distance_nearest_wood
        #   1x amount
        #
        #   5x direction_nearest_coal
        #   1x distance_nearest_coal
        #   1x amount
        #
        #   5x direction_nearest_uranium
        #   1x distance_nearest_uranium
        #   1x amount
        #
        #   5x direction_nearest_city
        #   1x distance_nearest_city
        #   1x amount of fuel
        #
        #   28x (the same as above, but direction, distance, and amount to the furthest of each)
        #
        #   5x direction_nearest_worker
        #   1x distance_nearest_worker
        #   1x amount of cargo
        # Unit:
        #   1x cargo size
        # State:
        #   1x is night
        #   1x percent of game done
        #   2x citytile counts [cur player, opponent]
        #   2x worker counts [cur player, opponent]
        #   2x cart counts [cur player, opponent]
        #   1x research points [cur player]
        #   1x researched coal [cur player]
        #   1x researched uranium [cur player]
        self.observation_shape = (3 + 7 * 5 * 2 + 1 + 1 + 1 + 2 + 2 + 2 + 3,)
        self.observation_space = spaces.Box(low=0, high=1, shape=
        self.observation_shape, dtype=np.float16)

        self.object_nodes = {}

    def get_agent_type(self):
        """
        Returns the type of agent. Use AGENT for inference, and LEARNING for training a model.
        """
        if self.mode == "train":
            return Constants.AGENT_TYPE.LEARNING
        else:
            return Constants.AGENT_TYPE.AGENT

    def get_observation(self, game, unit, city_tile, team, is_new_turn):
        """
        Implements getting a observation from the current game for this unit or city
        """
        observation_index = 0
        if is_new_turn:
            # It's a new turn this event. This flag is set True for only the first observation from each turn.
            # Update any per-turn fixed observation space that doesn't change per unit/city controlled.

            # Build a list of object nodes by type for quick distance-searches
            self.object_nodes = {}

            # Add resources
            for cell in game.map.resources:
                if cell.resource.type not in self.object_nodes:
                    self.object_nodes[cell.resource.type] = np.array([[cell.pos.x, cell.pos.y]])
                else:
                    self.object_nodes[cell.resource.type] = np.concatenate(
                        (
                            self.object_nodes[cell.resource.type],
                            [[cell.pos.x, cell.pos.y]]
                        ),
                        axis=0
                    )

            # Add your own and opponent units
            for t in [team, (team + 1) % 2]:
                for u in game.state["teamStates"][team]["units"].values():
                    key = str(u.type)
                    if t != team:
                        key = str(u.type) + "_opponent"

                    if key not in self.object_nodes:
                        self.object_nodes[key] = np.array([[u.pos.x, u.pos.y]])
                    else:
                        self.object_nodes[key] = np.concatenate(
                            (
                                self.object_nodes[key],
                                [[u.pos.x, u.pos.y]]
                            )
                            , axis=0
                        )

            # Add your own and opponent cities
            for city in game.cities.values():
                for cells in city.city_cells:
                    key = "city"
                    if city.team != team:
                        key = "city_opponent"

                    if key not in self.object_nodes:
                        self.object_nodes[key] = np.array([[cells.pos.x, cells.pos.y]])
                    else:
                        self.object_nodes[key] = np.concatenate(
                            (
                                self.object_nodes[key],
                                [[cells.pos.x, cells.pos.y]]
                            )
                            , axis=0
                        )

        # Observation space: (Basic minimum for a miner agent)
        # Object:
        #   1x is worker
        #   1x is cart
        #   1x is citytile
        #   5x direction_nearest_wood
        #   1x distance_nearest_wood
        #   1x amount
        #
        #   5x direction_nearest_coal
        #   1x distance_nearest_coal
        #   1x amount
        #
        #   5x direction_nearest_uranium
        #   1x distance_nearest_uranium
        #   1x amount
        #
        #   5x direction_nearest_city
        #   1x distance_nearest_city
        #   1x amount of fuel
        #
        #   5x direction_nearest_worker
        #   1x distance_nearest_worker
        #   1x amount of cargo
        #
        #   28x (the same as above, but direction, distance, and amount to the furthest of each)
        #
        # Unit:
        #   1x cargo size
        # State:
        #   1x is night
        #   1x percent of game done
        #   2x citytile counts [cur player, opponent]
        #   2x worker counts [cur player, opponent]
        #   2x cart counts [cur player, opponent]
        #   1x research points [cur player]
        #   1x researched coal [cur player]
        #   1x researched uranium [cur player]
        obs = np.zeros(self.observation_shape)
        
        # Update the type of this object
        #   1x is worker
        #   1x is cart
        #   1x is citytile
        observation_index = 0
        if unit is not None:
            if unit.type == Constants.UNIT_TYPES.WORKER:
                obs[observation_index] = 1.0 # Worker
            else:
                obs[observation_index+1] = 1.0 # Cart
        if city_tile is not None:
            obs[observation_index+2] = 1.0 # CityTile
        observation_index += 3
        
        pos = None
        if unit is not None:
            pos = unit.pos
        else:
            pos = city_tile.pos

        if pos is None:
            observation_index += 7 * 5 * 2
        else:
            # Encode the direction to the nearest objects
            #   5x direction_nearest
            #   1x distance
            for distance_function in [closest_node, furthest_node]:
                for key in [
                    Constants.RESOURCE_TYPES.WOOD,
                    Constants.RESOURCE_TYPES.COAL,
                    Constants.RESOURCE_TYPES.URANIUM,
                    "city",
                    str(Constants.UNIT_TYPES.WORKER)]:
                    # Process the direction to and distance to this object type

                    # Encode the direction to the nearest object (excluding itself)
                    #   5x direction
                    #   1x distance
                    if key in self.object_nodes:
                        if (
                                (key == "city" and city_tile is not None) or
                                (unit is not None and str(unit.type) == key and len(game.map.get_cell_by_pos(unit.pos).units) <= 1 )
                        ):
                            # Filter out the current unit from the closest-search
                            closest_index = closest_node((pos.x, pos.y), self.object_nodes[key])
                            filtered_nodes = np.delete(self.object_nodes[key], closest_index, axis=0)
                        else:
                            filtered_nodes = self.object_nodes[key]

                        if len(filtered_nodes) == 0:
                            # No other object of this type
                            obs[observation_index + 5] = 1.0
                        else:
                            # There is another object of this type
                            closest_index = distance_function((pos.x, pos.y), filtered_nodes)

                            if closest_index is not None and closest_index >= 0:
                                closest = filtered_nodes[closest_index]
                                closest_position = Position(closest[0], closest[1])
                                direction = pos.direction_to(closest_position)
                                mapping = {
                                    Constants.DIRECTIONS.CENTER: 0,
                                    Constants.DIRECTIONS.NORTH: 1,
                                    Constants.DIRECTIONS.WEST: 2,
                                    Constants.DIRECTIONS.SOUTH: 3,
                                    Constants.DIRECTIONS.EAST: 4,
                                }
                                obs[observation_index + mapping[direction]] = 1.0  # One-hot encoding direction

                                # 0 to 1 distance
                                distance = pos.distance_to(closest_position)
                                obs[observation_index + 5] = min(distance / 20.0, 1.0)

                                # 0 to 1 value (amount of resource, cargo for unit, or fuel for city)
                                if key == "city":
                                    # City fuel as % of upkeep for 200 turns
                                    c = game.cities[game.map.get_cell_by_pos(closest_position).city_tile.city_id]
                                    obs[observation_index + 6] = min(
                                        c.fuel / (c.get_light_upkeep() * 200.0),
                                        1.0
                                    )
                                elif key in [Constants.RESOURCE_TYPES.WOOD, Constants.RESOURCE_TYPES.COAL,
                                             Constants.RESOURCE_TYPES.URANIUM]:
                                    # Resource amount
                                    obs[observation_index + 6] = min(
                                        game.map.get_cell_by_pos(closest_position).resource.amount / 500,
                                        1.0
                                    )
                                else:
                                    # Unit cargo
                                    obs[observation_index + 6] = min(
                                        next(iter(game.map.get_cell_by_pos(
                                            closest_position).units.values())).get_cargo_space_left() / 100,
                                        1.0
                                    )

                    observation_index += 7

        if unit is not None:
            # Encode the cargo space
            #   1x cargo size
            obs[observation_index] = unit.get_cargo_space_left() / GAME_CONSTANTS["PARAMETERS"]["RESOURCE_CAPACITY"][
                "WORKER"]
            observation_index += 1
        else:
            observation_index += 1

        # Game state observations

        #   1x is night
        obs[observation_index] = game.is_night()
        observation_index += 1

        #   1x percent of game done
        obs[observation_index] = game.state["turn"] / GAME_CONSTANTS["PARAMETERS"]["MAX_DAYS"]
        observation_index += 1

        #   2x citytile counts [cur player, opponent]
        #   2x worker counts [cur player, opponent]
        #   2x cart counts [cur player, opponent]
        max_count = 30
        for key in ["city", str(Constants.UNIT_TYPES.WORKER), str(Constants.UNIT_TYPES.CART)]:
            if key in self.object_nodes:
                obs[observation_index] = len(self.object_nodes[key]) / max_count
            if (key + "_opponent") in self.object_nodes:
                obs[observation_index + 1] = len(self.object_nodes[(key + "_opponent")]) / max_count
            observation_index += 2

        #   1x research points [cur player]
        #   1x researched coal [cur player]
        #   1x researched uranium [cur player]
        obs[observation_index] = game.state["teamStates"][team]["researchPoints"] / 200.0
        obs[observation_index+1] = float(game.state["teamStates"][team]["researched"]["coal"])
        obs[observation_index+2] = float(game.state["teamStates"][team]["researched"]["uranium"])

        return obs

    def action_code_to_action(self, action_code, game, unit=None, city_tile=None, team=None):
        """
        Takes an action in the environment according to actionCode:
            actionCode: Index of action to take into the action array.
        Returns: An action.
        """
        # Map actionCode index into to a constructed Action object
        try:
            x = None
            y = None
            if city_tile is not None:
                x = city_tile.pos.x
                y = city_tile.pos.y
            elif unit is not None:
                x = unit.pos.x
                y = unit.pos.y
            
            if city_tile != None:
                action =  self.actionSpaceMapCities[action_code%len(self.actionSpaceMapCities)](
                    game=game,
                    unit_id=unit.id if unit else None,
                    unit=unit,
                    city_id=city_tile.city_id if city_tile else None,
                    citytile=city_tile,
                    team=team,
                    x=x,
                    y=y
                )

                # If the city action is invalid, default to research action automatically
                if not action.is_valid(game, actions_validated=[]):
                    action = ResearchAction(
                        game=game,
                        unit_id=unit.id if unit else None,
                        unit=unit,
                        city_id=city_tile.city_id if city_tile else None,
                        citytile=city_tile,
                        team=team,
                        x=x,
                        y=y
                    )
            else:
                action =  self.actionSpaceMapUnits[action_code%len(self.actionSpaceMapUnits)](
                    game=game,
                    unit_id=unit.id if unit else None,
                    unit=unit,
                    city_id=city_tile.city_id if city_tile else None,
                    citytile=city_tile,
                    team=team,
                    x=x,
                    y=y
                )
            
            return action
        except Exception as e:
            # Not a valid action
            print(e)
            return None

    def take_action(self, action_code, game, unit=None, city_tile=None, team=None):
        """
        Takes an action in the environment according to actionCode:
            actionCode: Index of action to take into the action array.
        """
        action = self.action_code_to_action(action_code, game, unit, city_tile, team)
        self.match_controller.take_action(action)
    
    def game_start(self, game):
        """
        This funciton is called at the start of each game. Use this to
        reset and initialize per game. Note that self.team may have
        been changed since last game. The game map has been created
        and starting units placed.

        Args:
            game ([type]): Game.
        """
        self.last_generated_fuel = game.stats["teamStats"][self.team]["fuelGenerated"]
        self.last_resources_collected = copy.deepcopy(game.stats["teamStats"][self.team]["resourcesCollected"])
        if self.stats != None:
            self.stats_last_game =  self.stats
        self.stats = {
            "rew/r_total": 0,
            "rew/r_wood": 0,
            "rew/r_coal": 0,
            "rew/r_uranium": 0,
            "rew/r_research": 0,
            "rew/r_city_tiles_end": 0,
            "rew/r_fuel_collected":0,
            "rew/r_units":0,
            "rew/r_city_tiles":0,
            "game/turns": 0,
            "game/research": 0,
            "game/unit_count": 0,
            "game/cart_count": 0,
            "game/city_count": 0,
            "game/city_tiles": 0,
            "game/wood_rate_mined": 0,
            "game/coal_rate_mined": 0,
            "game/uranium_rate_mined": 0,
        }
        self.is_last_turn = False

        # Calculate starting map resources
        type_map = {
            Constants.RESOURCE_TYPES.WOOD: "WOOD",
            Constants.RESOURCE_TYPES.COAL: "COAL",
            Constants.RESOURCE_TYPES.URANIUM: "URANIUM",
        }

        self.fuel_collected_last = 0
        self.fuel_start = {}
        self.fuel_last = {}
        for type, type_upper in type_map.items():
            self.fuel_start[type] = 0
            self.fuel_last[type] = 0
            for c in game.map.resources_by_type[type]:
                self.fuel_start[type] += c.resource.amount * game.configs["parameters"]["RESOURCE_TO_FUEL_RATE"][type_upper]

        self.research_last = 0
        self.units_last = 0
        self.city_tiles_last = 0

    def get_reward(self, game, is_game_finished, is_new_turn, is_game_error):
        """
        Returns the reward function for this step of the game.
        """
        if is_game_error:
            # Game environment step failed, assign a game lost reward to not incentivise this
            print("Game failed due to error")
            return -1.0

        if not is_new_turn and not is_game_finished:
            # Only apply rewards at the start of each turn
            return 0

        # Get some basic stats
        unit_count = len(game.state["teamStates"][self.team % 2]["units"])
        cart_count = 0
        for id, u in game.state["teamStates"][self.team % 2]["units"].items():
            if u.type == Constants.UNIT_TYPES.CART:
                cart_count += 1

        unit_count_opponent = len(game.state["teamStates"][(self.team + 1) % 2]["units"])
        research = min(game.state["teamStates"][self.team]["researchPoints"], 200.0) # Cap research points at 200
        city_count = 0
        city_count_opponent = 0
        city_tile_count = 0
        city_tile_count_opponent = 0
        for city in game.cities.values():
            if city.team == self.team:
                city_count += 1
            else:
                city_count_opponent += 1

            for cell in city.city_cells:
                if city.team == self.team:
                    city_tile_count += 1
                else:
                    city_tile_count_opponent += 1
        
        # Basic stats
        self.stats["game/research"] = research
        self.stats["game/city_tiles"] = city_tile_count
        self.stats["game/city_count"] = city_count
        self.stats["game/unit_count"] = unit_count
        self.stats["game/cart_count"] = cart_count
        self.stats["game/turns"] = game.state["turn"]

        rewards = {}

        # Give up to 1.0 reward for each resource based on % of total mined.
        type_map = {
            Constants.RESOURCE_TYPES.WOOD: "WOOD",
            Constants.RESOURCE_TYPES.COAL: "COAL",
            Constants.RESOURCE_TYPES.URANIUM: "URANIUM",
        }
        fuel_now = {}
        for type, type_upper in type_map.items():
            fuel_now = game.stats["teamStats"][self.team]["resourcesCollected"][type] * game.configs["parameters"]["RESOURCE_TO_FUEL_RATE"][type_upper]
            rewards["rew/r_%s" % type] = (fuel_now - self.fuel_last[type]) / self.fuel_start[type]
            self.stats["game/%s_rate_mined" % type] = fuel_now / self.fuel_start[type]
            self.fuel_last[type] = fuel_now
        
        # Give more incentive for coal and uranium
        rewards["rew/r_%s" % Constants.RESOURCE_TYPES.COAL] *= 2
        rewards["rew/r_%s" % Constants.RESOURCE_TYPES.URANIUM] *= 4
        
        # Give a reward based on amount of fuel collected. 1.0 reward for each 20K fuel gathered.
        fuel_collected = game.stats["teamStats"][self.team]["fuelGenerated"]
        rewards["rew/r_fuel_collected"] = ( (fuel_collected - self.fuel_collected_last) / 20000 )
        self.fuel_collected_last = fuel_collected

        # Give a reward for unit creation/death. 0.05 reward per unit.
        rewards["rew/r_units"] = (unit_count - self.units_last) * 0.05
        self.units_last = unit_count

        # Give a reward for unit creation/death. 0.1 reward per city.
        rewards["rew/r_city_tiles"] = (city_tile_count - self.city_tiles_last) * 0.1
        self.city_tiles_last = city_tile_count

        # Tiny reward for research to help. Up to 0.5 reward for this.
        rewards["rew/r_research"] = (research - self.research_last) / (200 * 2)
        self.research_last = research
        
        # Give a reward up to around 50.0 based on number of city tiles at the end of the game
        rewards["rew/r_city_tiles_end"] = 0
        if is_game_finished:
            self.is_last_turn = True
            rewards["rew/r_city_tiles_end"] = city_tile_count
        
        
        # Update the stats and total reward
        reward = 0
        for name, value in rewards.items():
            self.stats[name] += value
            reward += value
        self.stats["rew/r_total"] += reward

        # Print the final game stats sometimes
        if is_game_finished and random.random() <= 0.15:
            stats_string = []
            for key, value in self.stats.items():
                stats_string.append("%s=%.2f" % (key, value))
            print(",".join(stats_string))


        return reward
        
    

    def process_turn(self, game, team):
        """
        Decides on a set of actions for the current turn. Not used in training, only inference.
        Returns: Array of actions to perform.
        """
        start_time = time.time()
        actions = []
        new_turn = True

        # Inference the model per-unit
        units = game.state["teamStates"][team]["units"].values()
        for unit in units:
            if unit.can_act():
                obs = self.get_observation(game, unit, None, unit.team, new_turn)
                action_code, _states = self.model.predict(obs, deterministic=False)
                if action_code is not None:
                    actions.append(
                        self.action_code_to_action(action_code, game=game, unit=unit, city_tile=None, team=unit.team))
                new_turn = False

        # Inference the model per-city
        cities = game.cities.values()
        for city in cities:
            if city.team == team:
                for cell in city.city_cells:
                    city_tile = cell.city_tile
                    if city_tile.can_act():
                        obs = self.get_observation(game, None, city_tile, city.team, new_turn)
                        action_code, _states = self.model.predict(obs, deterministic=False)
                        if action_code is not None:
                            actions.append(
                                self.action_code_to_action(action_code, game=game, unit=None, city_tile=city_tile,
                                                           team=city.team))
                        new_turn = False

        time_taken = time.time() - start_time
        if time_taken > 0.5:  # Warn if larger than 0.5 seconds.
            print("WARNING: Inference took %.3f seconds for computing actions. Limit is 1 second." % time_taken,
                  file=sys.stderr)

        return actions
# Out:
# Overwriting agent_policy.py

# %% [markdown]
# # Build the environment for training
#
# Notes on metrics:
# * An Episode is a single game between your RL agent and it's opponent. This is generally 360 turns, spanning more than 360 unit + city decision steps.
# * Mean episode length (ep_len_mean) is the number of decision made per game. The larger this gets, means that it is making more unit + city decision per game, meaning that more units and cities were alive for longer during the game.
# * Episode reward mean (ep_rew_mean), is set up as micro-reward funciton for faster learning. Per turn it gets a small reward based on the number of cities and units alive. It gets a really big reward based on the number of cities and units alive at the end of the game.

# %%
pip install stable-baselines3
# Out:
# Requirement already satisfied: stable-baselines3 in /opt/conda/lib/python3.7/site-packages (1.7.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (1.2.4)
# Requirement already satisfied: torch>=1.11 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (1.13.1)
# Requirement already satisfied: typing-extensions<5,>=4.0 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (4.7.1)
# Requirement already satisfied: gym==0.21 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (0.21.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (1.19.5)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (1.6.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (3.4.2)
# Requirement already satisfied: importlib-metadata~=4.13 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata~=4.13->stable-baselines3) (3.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3) (11.7.99)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11->stable-baselines3) (0.36.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11->stable-baselines3) (49.6.0.post20210108)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (8.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->stable-baselines3) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->stable-baselines3) (2021.1)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Note: you may need to restart the kernel to use updated packages.

# %%
import argparse
import glob
import os
import random
from typing import Callable

from stable_baselines3 import A2C  # pip install stable-baselines3
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.vec_env import SubprocVecEnv

from importlib import reload
import agent_policy
 
from agent_policy import AgentPolicy

from luxai2021.env.agent import Agent
from luxai2021.env.lux_env import LuxEnvironment
from luxai2021.game.constants import LuxMatchConfigs_Default


# Default Lux configs
configs = LuxMatchConfigs_Default

# Create a default opponent agent
opponent = Agent()

# Create a RL agent in training mode
player = AgentPolicy(mode="train")

# Create the Lux environment
env = LuxEnvironment(configs=configs,
                     learning_agent=player,
                     opponent_agent=opponent)

# Define the model, you can pick other RL algos from Stable Baselines3 instead if you like
model = A2C("MlpPolicy",
                env,
                verbose=1,
                tensorboard_log="./lux_tensorboard/",
                learning_rate=0.001,
                gamma=0.999,
                gae_lambda=0.95,
              
                n_steps=2048 * 8
            )

# Define a learning rate schedule
# (number of steps, learning_rate)
schedule = [
    #(2000000, 0.01),
    (6000000, 0.001),
    (6000000, 0.0001),
]
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Running in inference-only mode.

# %% [markdown]
# # Train the agent against a dummy opponent

# %%
from stable_baselines3.common.utils import get_schedule_fn

print("Training model...")
run_id = 1

# Save a checkpoint every 1M steps
checkpoint_callback = CheckpointCallback(save_freq=1000000,
                                         save_path='./models/',
                                         name_prefix=f'rl_model_{run_id}')

# Train the policy
for steps, learning_rate in schedule:
    model.lr_schedule = get_schedule_fn(learning_rate)
    model.learn(total_timesteps=steps,
                callback=checkpoint_callback,
                reset_num_timesteps = False)

# Save final model
model.save(path=f'models/model.zip')

print("Done training model.")
# Out:
# Training model...
# Logging to ./lux_tensorboard/A2C_0
# rew/r_total=0.06,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=76.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=73.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=156.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=34.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=3.42,rew/r_wood=0.87,rew/r_coal=0.03,rew/r_uranium=0.00,rew/r_research=0.17,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.10,rew/r_units=0.05,rew/r_city_tiles=0.20,game/turns=351.00,game/research=68.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=2.00,game/wood_rate_mined=0.87,game/coal_rate_mined=0.02,game/uranium_rate_mined=0.00
# rew/r_total=0.09,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=198.00,game/research=6.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=34.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=76.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.20,rew/r_wood=0.16,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=156.00,game/research=15.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.16,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=191.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=33.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.09,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=192.00,game/research=10.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.08,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=191.00,game/research=12.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=72.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.15,rew/r_wood=0.08,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=198.00,game/research=7.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.08,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.07,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=191.00,game/research=10.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.33,rew/r_wood=0.26,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=311.00,game/research=20.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.26,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=32.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.11,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=151.00,game/research=15.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.23,rew/r_wood=0.12,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=198.00,game/research=19.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.12,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.13,rew/r_wood=0.10,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=231.00,game/research=12.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.10,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.10,rew/r_wood=0.08,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=72.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.08,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=196.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=76.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=1.48,rew/r_wood=0.29,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=198.00,game/research=17.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.29,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.51,rew/r_wood=0.20,rew/r_coal=0.02,rew/r_uranium=0.00,rew/r_research=0.14,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.06,rew/r_units=0.10,rew/r_city_tiles=0.00,game/turns=360.00,game/research=55.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.20,game/coal_rate_mined=0.01,game/uranium_rate_mined=0.00
# rew/r_total=0.10,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=198.00,game/research=6.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.15,rew/r_wood=0.11,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=236.00,game/research=14.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.11,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.04,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.12,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=237.00,game/research=14.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.11,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=113.00,game/research=13.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.14,rew/r_wood=0.08,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=271.00,game/research=21.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.08,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=32.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=1.30,rew/r_wood=0.10,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.01,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=194.00,game/research=14.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.10,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.09,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=78.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.07,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=156.00,game/research=13.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.09,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=77.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.07,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=75.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.13,rew/r_wood=0.09,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=273.00,game/research=14.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.09,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=6.37,rew/r_wood=0.54,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.15,rew/r_city_tiles_end=5.00,rew/r_fuel_collected=0.08,rew/r_units=0.10,rew/r_city_tiles=0.50,game/turns=198.00,game/research=59.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=5.00,game/wood_rate_mined=0.54,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=32.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.26,rew/r_wood=0.14,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.08,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=317.00,game/research=33.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.14,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=37.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.04,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=151.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.17,rew/r_wood=0.10,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.06,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=233.00,game/research=24.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.10,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.12,rew/r_wood=0.09,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=74.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.09,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.08,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=157.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=35.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=32.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=33.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.21,rew/r_wood=0.16,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=314.00,game/research=16.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.16,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.11,rew/r_wood=0.08,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=74.00,game/research=10.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.08,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.11,rew/r_wood=0.08,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=151.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.08,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.13,rew/r_wood=0.10,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=113.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.10,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.10,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=151.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.04,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=159.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.09,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=151.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.51,rew/r_wood=0.33,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.09,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=360.00,game/research=36.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.33,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.08,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=235.00,game/research=12.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.10,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=10.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.09,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=320.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.17,rew/r_wood=0.12,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=151.00,game/research=13.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.12,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.08,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=13.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=74.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=72.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=36.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.11,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=158.00,game/research=15.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.13,rew/r_wood=0.11,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=236.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.11,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=32.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=5.48,rew/r_wood=0.51,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.18,rew/r_city_tiles_end=4.00,rew/r_fuel_collected=0.10,rew/r_units=0.30,rew/r_city_tiles=0.40,game/turns=320.00,game/research=70.00,game/unit_count=6.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=4.00,game/wood_rate_mined=0.51,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.09,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.04,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.04,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=153.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.09,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=151.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=37.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=24.12,rew/r_wood=1.24,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.33,rew/r_city_tiles_end=20.00,rew/r_fuel_collected=0.19,rew/r_units=0.35,rew/r_city_tiles=2.00,game/turns=193.00,game/research=132.00,game/unit_count=7.00,game/cart_count=1.00,game/city_count=7.00,game/city_tiles=20.00,game/wood_rate_mined=1.24,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=35.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.04,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=37.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=37.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.07,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=151.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.11,rew/r_wood=0.08,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=154.00,game/research=12.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.08,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.71,rew/r_wood=0.41,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.14,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.07,rew/r_units=0.10,rew/r_city_tiles=0.00,game/turns=360.00,game/research=55.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.41,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=73.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.09,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=79.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=37.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.16,rew/r_wood=0.12,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=151.00,game/research=13.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.12,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.10,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=160.00,game/research=14.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.09,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=13.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=72.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.04,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=38.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=8.54,rew/r_wood=1.34,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.20,rew/r_city_tiles_end=6.00,rew/r_fuel_collected=0.09,rew/r_units=0.30,rew/r_city_tiles=0.60,game/turns=360.00,game/research=81.00,game/unit_count=6.00,game/cart_count=0.00,game/city_count=6.00,game/city_tiles=6.00,game/wood_rate_mined=1.34,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.15,rew/r_wood=0.09,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=315.00,game/research=18.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.09,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=37.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.19,rew/r_wood=0.13,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=116.00,game/research=21.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.13,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=32.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.36,rew/r_wood=0.26,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.08,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=275.00,game/research=31.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.26,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.04,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=77.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ...
# rew/r_total=0.92,rew/r_wood=0.63,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.26,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=-0.00,rew/r_city_tiles=-0.00,game/turns=274.00,game/research=102.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.63,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=2.70,rew/r_wood=0.25,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.18,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.02,rew/r_units=0.05,rew/r_city_tiles=0.20,game/turns=198.00,game/research=73.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=2.00,game/wood_rate_mined=0.25,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=3.09,rew/r_wood=0.56,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.26,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.02,rew/r_units=0.05,rew/r_city_tiles=0.20,game/turns=360.00,game/research=105.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=2.00,game/wood_rate_mined=0.56,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.83,rew/r_wood=0.61,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.17,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.05,rew/r_units=-0.00,rew/r_city_tiles=-0.00,game/turns=271.00,game/research=68.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.61,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.34,rew/r_wood=0.20,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.12,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=-0.00,rew/r_city_tiles=-0.00,game/turns=196.00,game/research=46.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.20,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=28.58,rew/r_wood=0.82,rew/r_coal=0.55,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=23.00,rew/r_fuel_collected=0.35,rew/r_units=1.05,rew/r_city_tiles=2.30,game/turns=360.00,game/research=200.00,game/unit_count=21.00,game/cart_count=0.00,game/city_count=5.00,game/city_tiles=23.00,game/wood_rate_mined=0.82,game/coal_rate_mined=0.28,game/uranium_rate_mined=0.00
# rew/r_total=13.30,rew/r_wood=0.45,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.20,rew/r_city_tiles_end=11.00,rew/r_fuel_collected=0.05,rew/r_units=0.50,rew/r_city_tiles=1.10,game/turns=198.00,game/research=78.00,game/unit_count=10.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=11.00,game/wood_rate_mined=0.45,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=30.70,rew/r_wood=1.27,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=25.00,rew/r_fuel_collected=0.18,rew/r_units=1.25,rew/r_city_tiles=2.50,game/turns=359.00,game/research=200.00,game/unit_count=25.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=25.00,game/wood_rate_mined=1.27,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.26e+03 |
# |    ep_rew_mean        | 6.34     |
# | time/                 |          |
# |    fps                | 598      |
# |    iterations         | 100      |
# |    time_elapsed       | 2739     |
# |    total_timesteps    | 7651328  |
# | train/                |          |
# |    entropy_loss       | -0.809   |
# |    explained_variance | 0.373    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 466      |
# |    policy_loss        | 0.0189   |
# |    value_loss         | 0.375    |
# ------------------------------------
# rew/r_total=0.65,rew/r_wood=0.47,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.18,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=-0.00,rew/r_city_tiles=-0.00,game/turns=358.00,game/research=70.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.47,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=12.85,rew/r_wood=0.83,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=10.00,rew/r_fuel_collected=0.03,rew/r_units=0.50,rew/r_city_tiles=1.00,game/turns=360.00,game/research=200.00,game/unit_count=10.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=10.00,game/wood_rate_mined=0.83,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.79,rew/r_wood=0.57,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.21,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=-0.00,rew/r_city_tiles=0.00,game/turns=273.00,game/research=83.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.57,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=7.50,rew/r_wood=0.48,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.11,rew/r_city_tiles_end=6.00,rew/r_fuel_collected=0.01,rew/r_units=0.30,rew/r_city_tiles=0.60,game/turns=198.00,game/research=44.00,game/unit_count=6.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=6.00,game/wood_rate_mined=0.48,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=7.22,rew/r_wood=0.13,rew/r_coal=0.02,rew/r_uranium=0.00,rew/r_research=0.19,rew/r_city_tiles_end=6.00,rew/r_fuel_collected=0.04,rew/r_units=0.25,rew/r_city_tiles=0.60,game/turns=198.00,game/research=74.00,game/unit_count=5.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=6.00,game/wood_rate_mined=0.13,game/coal_rate_mined=0.01,game/uranium_rate_mined=0.00
# rew/r_total=7.88,rew/r_wood=0.78,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.15,rew/r_city_tiles_end=6.00,rew/r_fuel_collected=0.04,rew/r_units=0.30,rew/r_city_tiles=0.60,game/turns=198.00,game/research=60.00,game/unit_count=6.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=6.00,game/wood_rate_mined=0.78,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.58,rew/r_wood=0.44,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.13,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=315.00,game/research=52.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.44,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=23.91,rew/r_wood=1.54,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.45,rew/r_city_tiles_end=19.00,rew/r_fuel_collected=0.07,rew/r_units=0.95,rew/r_city_tiles=1.90,game/turns=198.00,game/research=180.00,game/unit_count=19.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=19.00,game/wood_rate_mined=1.54,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=14.99,rew/r_wood=0.79,rew/r_coal=0.21,rew/r_uranium=0.00,rew/r_research=0.19,rew/r_city_tiles_end=12.00,rew/r_fuel_collected=0.05,rew/r_units=0.55,rew/r_city_tiles=1.20,game/turns=198.00,game/research=75.00,game/unit_count=11.00,game/cart_count=1.00,game/city_count=2.00,game/city_tiles=12.00,game/wood_rate_mined=0.79,game/coal_rate_mined=0.11,game/uranium_rate_mined=0.00
# rew/r_total=0.49,rew/r_wood=0.23,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.15,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.10,rew/r_city_tiles=0.00,game/turns=198.00,game/research=60.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.23,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=2.70,rew/r_wood=0.25,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.14,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.01,rew/r_units=0.10,rew/r_city_tiles=0.20,game/turns=360.00,game/research=55.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=2.00,game/wood_rate_mined=0.25,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=1.70,rew/r_wood=0.40,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.15,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=360.00,game/research=60.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.40,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=9.63,rew/r_wood=0.25,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.16,rew/r_city_tiles_end=8.00,rew/r_fuel_collected=0.02,rew/r_units=0.40,rew/r_city_tiles=0.80,game/turns=198.00,game/research=63.00,game/unit_count=8.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=8.00,game/wood_rate_mined=0.25,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=4.88,rew/r_wood=0.22,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.10,rew/r_city_tiles_end=4.00,rew/r_fuel_collected=0.01,rew/r_units=0.15,rew/r_city_tiles=0.40,game/turns=198.00,game/research=38.00,game/unit_count=3.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=4.00,game/wood_rate_mined=0.22,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=13.83,rew/r_wood=0.83,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.23,rew/r_city_tiles_end=11.00,rew/r_fuel_collected=0.07,rew/r_units=0.60,rew/r_city_tiles=1.10,game/turns=198.00,game/research=91.00,game/unit_count=12.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=11.00,game/wood_rate_mined=0.83,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.45,rew/r_wood=0.23,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.22,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=318.00,game/research=87.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.23,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=2.77,rew/r_wood=0.33,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.12,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.01,rew/r_units=0.10,rew/r_city_tiles=0.20,game/turns=360.00,game/research=49.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=2.00,game/wood_rate_mined=0.33,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=15.28,rew/r_wood=0.94,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.49,rew/r_city_tiles_end=12.00,rew/r_fuel_collected=0.05,rew/r_units=0.60,rew/r_city_tiles=1.20,game/turns=360.00,game/research=194.00,game/unit_count=12.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=12.00,game/wood_rate_mined=0.94,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=15.75,rew/r_wood=0.52,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.24,rew/r_city_tiles_end=13.00,rew/r_fuel_collected=0.04,rew/r_units=0.65,rew/r_city_tiles=1.30,game/turns=198.00,game/research=94.00,game/unit_count=13.00,game/cart_count=0.00,game/city_count=4.00,game/city_tiles=13.00,game/wood_rate_mined=0.52,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=3.87,rew/r_wood=0.34,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.07,rew/r_city_tiles_end=3.00,rew/r_fuel_collected=0.01,rew/r_units=0.15,rew/r_city_tiles=0.30,game/turns=198.00,game/research=26.00,game/unit_count=3.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=3.00,game/wood_rate_mined=0.34,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=1.90,rew/r_wood=0.51,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.16,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.03,rew/r_units=0.10,rew/r_city_tiles=0.10,game/turns=198.00,game/research=63.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.51,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.88,rew/r_wood=0.56,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.29,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.00,rew/r_city_tiles=-0.00,game/turns=357.00,game/research=117.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.56,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=6.43,rew/r_wood=0.49,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.15,rew/r_city_tiles_end=5.00,rew/r_fuel_collected=0.04,rew/r_units=0.25,rew/r_city_tiles=0.50,game/turns=360.00,game/research=60.00,game/unit_count=5.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=5.00,game/wood_rate_mined=0.49,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=2.86,rew/r_wood=1.47,rew/r_coal=0.00,rew/r_uranium=0.73,rew/r_research=0.50,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.10,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=360.00,game/research=200.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=1.47,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-b362642e011f> in <module>
#      14     model.learn(total_timesteps=steps,
#      15                 callback=checkpoint_callback,
# ---> 16                 reset_num_timesteps = False)
#      17
#      18 # Save final model
#
# /opt/conda/lib/python3.7/site-packages/stable_baselines3/a2c/a2c.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     197             tb_log_name=tb_log_name,
#     198             reset_num_timesteps=reset_num_timesteps,
# --> 199             progress_bar=progress_bar,
#     200         )
#
# /opt/conda/lib/python3.7/site-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     246         while self.num_timesteps < total_timesteps:
#     247
# --> 248             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     249
#     250             if continue_training is False:
#
# /opt/conda/lib/python3.7/site-packages/stable_baselines3/common/on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     173                 clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     174
# --> 175             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     176
#     177             self.num_timesteps += env.num_envs
#
# /opt/conda/lib/python3.7/site-packages/stable_baselines3/common/vec_env/base_vec_env.py in step(self, actions)
#     161         """
#     162         self.step_async(actions)
# --> 163         return self.step_wait()
#     164
#     165     def get_images(self) -> Sequence[np.ndarray]:
#
# /opt/conda/lib/python3.7/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in step_wait(self)
#      53         for env_idx in range(self.num_envs):
#      54             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
# ---> 55                 self.actions[env_idx]
#      56             )
#      57             if self.buf_dones[env_idx]:
#
# /opt/conda/lib/python3.7/site-packages/stable_baselines3/common/monitor.py in step(self, action)
#      92         if self.needs_reset:
#      93             raise RuntimeError("Tried to step environment that needs reset")
# ---> 94         observation, reward, done, info = self.env.step(action)
#      95         self.rewards.append(reward)
#      96         if done:
#
# /opt/conda/lib/python3.7/site-packages/luxai2021/env/lux_env.py in step(self, action_code)
#     128         """
#     129         # Decision for 1 unit or city
# --> 130         self.learning_agent.take_action(action_code,
#     131                                         self.game,
#     132                                         unit=self.last_observation_object[0],
#
# KeyboardInterrupt:

# %%
# Save final model
model.save(path=f'models/model.zip')

print("Done training model.")
# Out:
# Done training model.
# /opt/conda/lib/python3.7/site-packages/stable_baselines3/common/save_util.py:278: UserWarning: Path 'models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %% [markdown]
# # Set up a Kaggle Submission and lux replay environment for the agent

# %%
"""
This downloads two required python package dependencies that are not pre-installed
by Kaggle yet.

This places the following two packages in the current working directory:
    luxai2021
    stable_baselines3
"""

import os
import shutil
import subprocess
import tempfile

def localize_package(git, branch, folder):
    if os.path.exists(folder):
        print("Already localized %s" % folder)
    else:
        # https://stackoverflow.com/questions/51239168/how-to-download-single-file-from-a-git-repository-using-python
        # Create temporary dir
        t = tempfile.mkdtemp()

        args = ['git', 'clone', '--depth=1', git, t, '-b', branch]
        res = subprocess.Popen(args, stdout=subprocess.PIPE)
        output, _error = res.communicate()

        if not _error:
            print(output)
        else:
            print(_error)
        
        # Copy desired file from temporary dir
        shutil.move(os.path.join(t, folder), '.')
        # Remove temporary dir
        shutil.rmtree(t, ignore_errors=True)

localize_package('https://github.com/devanshi00/LuxPythonEnvGym', 'main', 'luxai2021')
localize_package('https://github.com/devanshi00/LuxPythonEnvGym', 'main', 'kaggle_submissions')
localize_package('https://github.com/DLR-RM/stable-baselines3.git', 'master', 'stable_baselines3')
# Out:
# Already localized luxai2021
# Already localized kaggle_submissions
# Already localized stable_baselines3

# %%
import shutil
src_path = r"/kaggle/input/get-csv/type_aliases.py"
dst_path = r"/kaggle/working/kaggle_submissions/stable_baselines3/common"

# %%
shutil.copy(src_path, dst_path)
print('Copied')
# Out:
# Copied

# %%
# !rm ./kaggle_submissions/stable_baselines3/common/type_aliases.py

# %%
# Move the dependent packages into kaggle submissions
# !mv luxai2021 kaggle_submissions
# !mv stable_baselines3 kaggle_submissions
# !rm ./kaggle_submissions/agent_policy.py
# !cp agent_policy.py kaggle_submissions

# Copy the agent and model to the submission 
# !cp ./agent_policy.py kaggle_submissions
# !cp ./models/rl_model_1_7000000_steps.zip kaggle_submissions

# !ls kaggle_submissions
# Out:
# rm: cannot remove './kaggle_submissions/agent_policy.py': No such file or directory
# agent_policy.py		  main.py			stable_baselines3
# download_dependencies.py  main_lux-ai-2021.py
# luxai2021		  rl_model_1_7000000_steps.zip

# %%
# !rm ./kaggle_submissions/main_lux-ai-2021.py

# %%
# !cp ./kaggle/input/file-csv/main_lux-ai-2021.py kaggle_submissions
# Out:
# cp: cannot stat './kaggle/input/file-csv/main_lux-ai-2021.py': No such file or directory

# %%
pip install stable-baselines3
# Out:
# Requirement already satisfied: stable-baselines3 in /opt/conda/lib/python3.7/site-packages (1.7.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (1.19.5)
# Requirement already satisfied: importlib-metadata~=4.13 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (4.13.0)
# Requirement already satisfied: gym==0.21 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (0.21.0)
# Requirement already satisfied: typing-extensions<5,>=4.0 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (4.7.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (1.2.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (3.4.2)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (1.6.0)
# Requirement already satisfied: torch>=1.11 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (1.13.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata~=4.13->stable-baselines3) (3.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3) (11.7.99)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3) (8.5.0.96)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11->stable-baselines3) (49.6.0.post20210108)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11->stable-baselines3) (0.36.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (8.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (0.10.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->stable-baselines3) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->stable-baselines3) (2021.1)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gymnasium
# Out:
# Collecting gymnasium
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      |████████████████████████████████| 925 kB 4.3 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium) (4.7.1)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium) (4.13.0)
# Collecting numpy>=1.21.0
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 31.0 MB/s eta 0:00:01
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium) (1.6.0)
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting jax-jumpy>=1.0.0
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=4.8.0->gymnasium) (3.4.1)
# Installing collected packages: numpy, jax-jumpy, farama-notifications, gymnasium
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.21.6 which is incompatible.
# tensorflow 2.4.1 requires numpy~=1.19.2, but you have numpy 1.21.6 which is incompatible.
# tensorflow 2.4.1 requires typing-extensions~=3.7.4, but you have typing-extensions 4.7.1 which is incompatible.
# pdpbox 0.2.1 requires matplotlib==3.1.1, but you have matplotlib 3.4.2 which is incompatible.
# matrixprofile 1.1.10 requires protobuf==3.11.2, but you have protobuf 3.17.3 which is incompatible.
# luxai2021 0.1.0 requires gym==0.19.0, but you have gym 0.21.0 which is incompatible.
# luxai2021 0.1.0 requires stable-baselines3==1.2.1a2, but you have stable-baselines3 1.7.0 which is incompatible.
# kornia 0.5.5 requires numpy<=1.19, but you have numpy 1.21.6 which is incompatible.
# imbalanced-learn 0.8.0 requires scikit-learn>=0.24, but you have scikit-learn 0.23.2 which is incompatible.
# fastai 2.2.7 requires torch<1.8,>=1.7.0, but you have torch 1.13.1 which is incompatible.
# arviz 0.11.2 requires typing-extensions<4,>=3.7.4.3, but you have typing-extensions 4.7.1 which is incompatible.
# allennlp 2.5.0 requires torch<1.9.0,>=1.6.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0 numpy-1.21.6
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
pip install typing_extensions
# Out:
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.7/site-packages (4.7.1)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Note: you may need to restart the kernel to use updated packages.

# %%
from kaggle_environments import make
import json
# run another match but with our empty agent
env = make("lux_ai_2021", configuration={"seed": 5621242, "loglevel": 2, "annotations": True}, debug=True)

# Play the environment where the RL agent plays against itself
steps = env.run(["./kaggle_submissions/main.py", "./kaggle_submissions/main.py"])
# Out:
# /kaggle/working/kaggle_submissions/stable_baselines3/common/vec_env/patch_gym.py:96: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   "You loaded a model that was trained using OpenAI Gym. "
# Running in inference-only mode.
# /kaggle/working/kaggle_submissions/stable_baselines3/common/vec_env/patch_gym.py:96: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   "You loaded a model that was trained using OpenAI Gym. "
# Running in inference-only mode.
# [WARN] (match_x18I9QcGxolC) - turn 49; Unit u_6 collided when trying to move e to (3, 3)
# [WARN] (match_x18I9QcGxolC) - turn 55; Unit u_4 collided when trying to move e to (3, 5)
# [WARN] (match_x18I9QcGxolC) - turn 91; Unit u_18 collided when trying to move n to (4, 11)
# [WARN] (match_x18I9QcGxolC) - turn 98; Unit u_12 collided when trying to move s to (11, 4)
# [WARN] (match_x18I9QcGxolC) - turn 101; Unit u_12 collided when trying to move s to (10, 4)
# [WARN] (match_x18I9QcGxolC) - turn 102; Unit u_23 collided when trying to move n to (10, 3)
# [WARN] (match_x18I9QcGxolC) - turn 126; Unit u_11 collided when trying to move w to (3, 2)
# [WARN] (match_x18I9QcGxolC) - turn 129; Unit u_25 collided when trying to move s to (11, 5)
# [WARN] (match_x18I9QcGxolC) - turn 143; Unit u_26 collided when trying to move e to (4, 2)
# [WARN] (match_x18I9QcGxolC) - turn 167; Unit u_25 collided when trying to move n to (12, 1)
# [WARN] (match_x18I9QcGxolC) - turn 171; Unit u_45 collided when trying to move n to (5, 2)
# [WARN] (match_x18I9QcGxolC) - turn 174; Unit u_43 collided when trying to move w to (2, 6)
# [WARN] (match_x18I9QcGxolC) - turn 186; Unit u_45 collided when trying to move n to (5, 2)
# [WARN] (match_x18I9QcGxolC) - turn 189; Unit u_37 collided when trying to move w to (5, 2)
# [WARN] (match_x18I9QcGxolC) - turn 189; Unit u_50 collided when trying to move s to (4, 3)
# [WARN] (match_x18I9QcGxolC) - turn 210; Unit u_69 collided when trying to move s to (11, 3)
# [WARN] (match_x18I9QcGxolC) - turn 212; Unit u_55 collided when trying to move s to (4, 3)
# [WARN] (match_x18I9QcGxolC) - turn 213; Unit u_55 collided when trying to move s to (4, 3)
# [WARN] (match_x18I9QcGxolC) - turn 217; Unit u_66 collided when trying to move n to (4, 10)
# [WARN] (match_x18I9QcGxolC) - turn 217; Unit u_72 collided when trying to move n to (12, 1)
# [WARN] (match_x18I9QcGxolC) - turn 218; Unit u_72 collided when trying to move n to (12, 1)
# [WARN] (match_x18I9QcGxolC) - turn 220; Unit u_72 collided when trying to move n to (12, 1)
# [WARN] (match_x18I9QcGxolC) - turn 221; Unit u_73 collided when trying to move s to (2, 5)
# [WARN] (match_x18I9QcGxolC) - turn 221; Unit u_72 collided when trying to move n to (12, 1)
# [WARN] (match_x18I9QcGxolC) - turn 226; Unit u_73 collided when trying to move s to (2, 5)
# [WARN] (match_x18I9QcGxolC) - turn 227; Unit u_25 collided when trying to move n to (11, 3)
# [WARN] (match_x18I9QcGxolC) - turn 228; Unit u_28 collided when trying to move s to (11, 3)
# [WARN] (match_x18I9QcGxolC) - turn 229; Unit u_25 collided when trying to move n to (11, 3)
# [WARN] (match_x18I9QcGxolC) - turn 230; Unit u_25 collided when trying to move n to (11, 3)
# [WARN] (match_x18I9QcGxolC) - turn 242; Unit u_28 collided when trying to move n to (11, 1)
# [WARN] (match_x18I9QcGxolC) - turn 254; Unit u_59 collided when trying to move s to (1, 5)
# [WARN] (match_x18I9QcGxolC) - turn 256; Unit u_73 collided when trying to move s to (1, 5)
# [WARN] (match_x18I9QcGxolC) - turn 262; Unit u_89 collided when trying to move n to (13, 5)
# [WARN] (match_x18I9QcGxolC) - turn 263; Unit u_96 collided when trying to move e to (4, 3)
# [WARN] (match_x18I9QcGxolC) - turn 264; Unit u_78 collided when trying to move n to (1, 2)
# [WARN] (match_x18I9QcGxolC) - turn 268; Unit u_86 collided when trying to move s to (5, 3)

# %%
# !pip install 'shimmy>=0.2.1'
# Out:
# Collecting shimmy>=0.2.1
#   Downloading Shimmy-1.1.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: gymnasium>=0.27.0 in /opt/conda/lib/python3.7/site-packages (from shimmy>=0.2.1) (0.28.1)
# Requirement already satisfied: numpy>=1.18.0 in /opt/conda/lib/python3.7/site-packages (from shimmy>=0.2.1) (1.21.6)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium>=0.27.0->shimmy>=0.2.1) (4.7.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium>=0.27.0->shimmy>=0.2.1) (1.0.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/lib/python3.7/site-packages (from gymnasium>=0.27.0->shimmy>=0.2.1) (0.0.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium>=0.27.0->shimmy>=0.2.1) (1.6.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium>=0.27.0->shimmy>=0.2.1) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=4.8.0->gymnasium>=0.27.0->shimmy>=0.2.1) (3.4.1)
# Installing collected packages: shimmy
# Successfully installed shimmy-1.1.0
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
# !pip install --upgrade python==3.8
# Out:
# ERROR: Could not find a version that satisfies the requirement python==3.8 (from versions: none)
# ERROR: No matching distribution found for python==3.8

# %%
pip install --upgrade stable-baselines3
# Out:
# Requirement already satisfied: stable-baselines3 in /opt/conda/lib/python3.7/site-packages (1.7.0)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 4.4 MB/s eta 0:00:01
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (1.6.0)
# Requirement already satisfied: gymnasium==0.28.1 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (0.28.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (1.2.4)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (1.21.6)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (3.4.2)
# Requirement already satisfied: typing-extensions<5,>=4.0 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (4.7.1)
# Requirement already satisfied: torch>=1.11 in /opt/conda/lib/python3.7/site-packages (from stable-baselines3) (1.13.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/lib/python3.7/site-packages (from gymnasium==0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium==0.28.1->stable-baselines3) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium==0.28.1->stable-baselines3) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=4.8.0->gymnasium==0.28.1->stable-baselines3) (3.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.7/site-packages (from torch>=1.11->stable-baselines3) (8.5.0.96)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11->stable-baselines3) (0.36.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11->stable-baselines3) (49.6.0.post20210108)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable-baselines3) (8.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->stable-baselines3) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->stable-baselines3) (2021.1)
# Installing collected packages: stable-baselines3
#   Attempting uninstall: stable-baselines3
#     Found existing installation: stable-baselines3 1.7.0
#     Uninstalling stable-baselines3-1.7.0:
#       Successfully uninstalled stable-baselines3-1.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# luxai2021 0.1.0 requires gym==0.19.0, but you have gym 0.21.0 which is incompatible.
# luxai2021 0.1.0 requires stable-baselines3==1.2.1a2, but you have stable-baselines3 2.0.0 which is incompatible.
# kaggle-environments 1.14.0 requires stable-baselines3==1.7.0, but you have stable-baselines3 2.0.0 which is incompatible.
# Successfully installed stable-baselines3-2.0.0
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Note: you may need to restart the kernel to use updated packages.

# %%
# Render the match
env.render(mode="ipython", width=1200, height=800)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;6083b8b2-bed9-11ee-9777-0242ac130202&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 5621242,
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
#       &quot;action&quot;: {
#         &quot;description&quot;: &quot;Actions&quot;,
#         &quot;type&quot;: &quot;array&quot;,
#         &quot;default&quot;: 0
#       },
#       &quot;agents&quot;: [
#         2
#       ],
#       &quot;configuration&quot;: {
#         &quot;episodeSteps&quot;: {
#           &quot;description&quot;: &quot;Maximum number of steps the environment can run. Total is this number -1. One complete game is 360 steps&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;minimum&quot;: 2,
#           &quot;default&quot;: 361
#         },
#         &quot;actTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) to obtain an action from an agent.&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 3
#         },
#         &quot;runTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) of an episode (not necessarily DONE).&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 1200
#         },
#         &quot;parameters&quot;: {
#           &quot;description&quot;: &quot;Parameters for Lux AI 2021&quot;,
#           &quot;type&quot;: &quot;object&quot;
#         },
#         &quot;mapType&quot;: {
#           &quot;description&quot;: &quot;Map type to use&quot;,
#           &quot;type&quot;: &quot;string&quot;,
#           &quot;default&quot;: &quot;random&quot;
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;Width of map to generate&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;seed&quot;: {
#           &quot;description&quot;: &quot;Seed to use for episodes&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;annotations&quot;: {
#           &quot;description&quot;: &quot;Whether to enable debug annotations or not.&quot;,
#           &quot;type&quot;: &quot;boolean&quot;,
#           &quot;default&quot;: false
#         },
#         &quot;loglevel&quot;: {
#           &quot;description&quot;: &quot;Logging level of the game. 2 for warnings (e.g unit collisions, malformed actions), 1 for errors, 0 for none&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         }
#       },
#       &quot;info&quot;: {},
#       &quot;observation&quot;: {
#         &quot;remainingOverageTime&quot;: {
#           &quot;description&quot;: &quot;Total remaining banked time (seconds) that can be used in excess of per-step actTimeouts -- agent is disqualified with TIMEOUT status when this drops below 0.&quot;,
#           &quot;shared&quot;: false,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 60
#         },
#         &quot;step&quot;: {
#           &quot;description&quot;: &quot;Current step within the episode.&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 0
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;The width of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;height&quot;: {
#           &quot;description&quot;: &quot;The height of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;reward&quot;: {
#           &quot;description&quot;: &quot;Current reward of the agent. Equal to number of city tiles * 10000 + number of units&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         },
#         &quot;updates&quot;: {
#           &quot;description&quot;: &quot;List of update strings for agents to use and generate the observed state&quot;,
#           &quot;type&quot;: &quot;array&quot;,
#           &quot;shared&quot;: true
#         },
#         &quot;globalUnitIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;globalCityIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;player&quot;: {
#           &quot;description&quot;: &quot;Current player's index / team id&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;defaults&quot;: [
#             0,
#             1
#           ]
#         }
#       },
#       &quot;reward&quot;: {
#         &quot;description&quot;: &quot;Reward of the agent. Equal to number of city tiles * 1000 + number of units&quot;,
#         &quot;type&quot;: [
#           &quot;number&quot;,
#           &quot;null&quot;
#         ],
#         &quot;default&quot;: 0
#       }
#     },
#     &quot;steps&quot;: [
#       [
#         {
#           &quot;action&quot;: [],
#           &quot;reward&quot;: 0,
#           &quot;info&quot;: {},
#           &quot;observation&quot;: {
#             &quot;remainingOverageTime&quot;: 60,
#             &quot;step&quot;: 0,
#             &quot;width&quot;: 16,
#             &quot;height&quot;: 16,
#             &quot;reward&quot;: 0,
#             &quot;globalUnitIDCount&quot;: 2,
#             &quot;globalCityIDCount&quot;: 2,
#             &quot;player&quot;: 0,
#             &quot;updates&quot;: [
#               &quot;0&quot;,
#               &quot;16 16&quot;,
#               &quot;rp 0 0&quot;,
#               &quot;rp 1 0&quot;,
#               &quot;r wood 0 3 800&quot;,
#               &quot;r wood 0 4 800&quot;,
#               &quot;r coal 0 6 405&quot;,
#               &quot;r coal 0 7 368&quot;,
#               &quot;r uranium 0 15 338&quot;,
#               &quot;r wood 1 4 800&quot;,
#               &quot;r wood 1 13 349&quot;,
#               &quot;r wood 2 11 354&quot;,
#               &quot;r wood 2 12 368&quot;,
#               &quot;r wood 3 3 374&quot;,
#               &quot;r wood 3 11 381&quot;,
#               &quot;r wood 3 12 376&quot;,
#               &quot;r wood 4 2 337&quot;,
#               &quot;r wood 4 3 391&quot;,
#               &quot;r wood 5 2 393&quot;,
#               &quot;r wood 5 3 375&quot;,
#               &quot;r coal 7 15 391&quot;,
#               &quot;r coal 8 15 391&quot;,
#               &quot;r wood 10 2 393&quot;,
#               &quot;r wood 10 3 375&quot;,
#               &quot;r wood 11 2 337&quot;,
#               &quot;r wood 11 3 391&quot;,
#               &quot;r wood 12 3 374&quot;,
#               &quot;r wood 12 11 381&quot;,
#               &quot;r wood 12 12 376&quot;,
#               &quot;r wood 13 11 354&quot;,
#               &quot;r wood 13 12 368&quot;,
#               &quot;r wood 14 4 800&quot;,
#               &quot;r wood 14 13 349&quot;,
#               &

# %% [markdown]
# # Prepare and submit the kaggle submission

# %%
# !tar -czf submission.tar.gz -C kaggle_submissions .
# !ls
# Out:
# __pycache__	    log.txt	     models
# agent_policy.py     lux_tensorboard  stable_baselines3
# kaggle_submissions  luxai2021	     submission.tar.gz
